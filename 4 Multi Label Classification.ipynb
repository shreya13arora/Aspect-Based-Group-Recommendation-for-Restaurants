# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Model-Building-on-Reviews-to-predict-the-Aspects" data-toc-modified-id="Model-Building-on-Reviews-to-predict-the-Aspects-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Model Building on Reviews to predict the Aspects</a></span><ul class="toc-item"><li><span><a href="#Importing-libraries" data-toc-modified-id="Importing-libraries-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Importing libraries</a></span></li><li><span><a href="#Pre-processing-on-reviews" data-toc-modified-id="Pre-processing-on-reviews-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Pre-processing on reviews</a></span></li></ul></li><li><span><a href="#Sentiment-Analysis" data-toc-modified-id="Sentiment-Analysis-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Sentiment Analysis</a></span><ul class="toc-item"><li><span><a href="#Test-Codes" data-toc-modified-id="Test-Codes-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Test Codes</a></span></li></ul></li><li><span><a href="#Restaurant-Ratings" data-toc-modified-id="Restaurant-Ratings-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Restaurant Ratings</a></span></li><li><span><a href="#User-weights" data-toc-modified-id="User-weights-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>User weights</a></span></li><li><span><a href="#Aspect-Dictionary-and-User-Weights" data-toc-modified-id="Aspect-Dictionary-and-User-Weights-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Aspect Dictionary and User Weights</a></span><ul class="toc-item"><li><span><a href="#Combined-Dataset" data-toc-modified-id="Combined-Dataset-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Combined Dataset</a></span></li></ul></li></ul></div>

# %% [markdown]
# ### Model Building on Reviews to predict the Aspects

# %% [markdown]
# #### Importing libraries

# %%
import os
#os.chdir(r"D:\Capstone Prep\Multi Label Classification")
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET
import warnings
import pickle

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from skmultilearn.problem_transform import LabelPowerset
import numpy as np

from gensim.test.utils import datapath, get_tmpfile
from gensim.models import KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec

from collections import Counter, defaultdict
import re
import gensim

import spacy
from spacy import displacy
nlp = spacy.load("en_core_web_sm")
# from neuralcoref import Coref
# coref = Coref(nlp=spacy)
# nlp= spacy.load("en_core_web_sm")

warnings.filterwarnings('ignore')

# %%
tree = ET.parse("Restaurants_Train.xml", ET.XMLParser(encoding= "utf-8"))
root = tree.getroot()

# %%
labeled_reviews = []
for sentence in root.findall("sentence"):
    entry = {}
    aterms = []
    aspects = []
    sentiment = []
    if sentence.find("aspectTerms"):
        for aterm in sentence.find("aspectTerms").findall("aspectTerm"):
            aterms.append(aterm.get("term"))
    if sentence.find("aspectCategories"):
        for aspect in sentence.find("aspectCategories"):
            aspects.append(aspect.get("category"))
        for aspect in sentence.find("aspectCategories"):
            sentiment.append(aspect.get("polarity"))
            
    entry["text"], entry["terms"], entry["aspects"], entry["sentiment"] = sentence[0].text, aterms, aspects, sentiment
    labeled_reviews.append(entry)
labeled_df = pd.DataFrame(labeled_reviews)
print("We have", len(labeled_reviews), "labeled reviews.")
# Out:
# We have 3044 labeled reviews.

# %%
# Save annotated reviews in a pickle file
labeled_df.to_pickle("annotated_reviews_df.pkl")

# Read annotated reviews df -> labeled dataset for training
annotated_reviews_df = pd.read_pickle("annotated_reviews_df.pkl")
annotated_reviews_df.head()
# Out:
#                                                 text                  terms  \
# 0               But the staff was so horrible to us.                [staff]
# 1  To be completely fair, the only redeeming fact...                 [food]
# 2  The food is uniformly exceptional, with a very...  [food, kitchen, menu]
# 3  Where Gabriela personaly greets you and recomm...                     []
# 4  For those that go once and don't enjoy it, all...                     []
#
#                            aspects             sentiment
# 0                        [service]            [negative]
# 1  [food, anecdotes/miscellaneous]  [positive, negative]
# 2                           [food]            [positive]
# 3                        [service]            [positive]
# 4        [anecdotes/miscellaneous]            [positive]

# %%
# Convert the multi-labels into arrays
mlb = MultiLabelBinarizer()
y = mlb.fit_transform(annotated_reviews_df.aspects) # aspects
X = annotated_reviews_df["text"] # reviews

# Split data into train and test set
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size= 0.25, random_state= 0)

# save the the fitted binarizer labels
filename = 'mlb.pkl'
pickle.dump(mlb, open(filename, 'wb'))

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2283,)
# (761,)
# (2283, 5)
# (761, 5)

# %% [markdown]
# #### Pre-processing on reviews

# %%
# Preprocessing methods: # https://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html
# https://towardsdatascience.com/tf-idf-explained-and-python-sklearn-implementation-b020c5e83275

# Text preprocessing, tokenizing and filtering of stopwords

# CountVectorizer supports counts of N-grams of words or consecutive characters. Once fitted, the vectorizer has built a 
# dictionary of feature indices

# TF-IDF: Term Frequency—Inverse Document Frequency: defines how important a word is for a document, while also taking into 
# account the relation to other documents from the same corpus. TF-IDF is a score which is applied to every word in every 
# document in our dataset. And for every word, the TF-IDF value increases with every appearance of the word in a document, 
# but is gradually decreased with every appearance in other documents. 

# CountVectorizer: To transform a count matrix to a normalized tf or tf-idf representation

# LabelPowerset allows for multi-label classification
# Build a pipeline for multinomial naive bayes classification

text_clf = Pipeline([('vect', CountVectorizer(stop_words = "english",ngram_range=(1, 1))),
                     ('tfidf', TfidfTransformer(use_idf=False)),
                     ('clf', LabelPowerset(MultinomialNB(alpha=1e-1))),])
text_clf = text_clf.fit(X_train, y_train)
predicted = text_clf.predict(X_test)

# Calculate accuracy
np.mean(predicted == y_test)
# Out:
# 0.8662286465177398

# %%
# Test if SVM performs better
from sklearn.linear_model import SGDClassifier
text_clf_svm = Pipeline([('vect', CountVectorizer()),
                         ('tfidf', TfidfTransformer()),
                         ('clf-svm', LabelPowerset(
                             SGDClassifier(loss='hinge', penalty='l2',
                                           alpha=1e-3, max_iter=6, random_state=42)))])
_ = text_clf_svm.fit(X_train, y_train)
predicted_svm = text_clf_svm.predict(X_test)

#Calculate accuracy
np.mean(predicted_svm == y_test)
# Out:
# 0.8633377135348226

# %%
# Train naive bayes on full dataset and save model
text_clf = Pipeline([('vect', CountVectorizer(stop_words = "english",ngram_range=(1, 1))),
                     ('tfidf', TfidfTransformer(use_idf=False)),
                     ('clf', LabelPowerset(MultinomialNB(alpha=1e-1))),])
text_clf = text_clf.fit(X, y)

# save the model to disk
filename = 'naive_model1.pkl'
pickle.dump(text_clf, open(filename, 'wb'))

# %%
# Prediction:

#mlb.inverse_transform(predicted)
pred_df = pd.DataFrame(
    {'reviews': X_test,
     'pred_category': mlb.inverse_transform(predicted)
    })

# %%
# pd.set_option('display.max_colwidth', -1)
pred_df
# Out:
#                                                 reviews  \
# 453   It's better than being on the roof of Sutton P...
# 1611  Don't expect to sit down inside though, there ...
# 2078  Again, if you are in this neighborhood - by al...
# 2715  Go there to relax and feel like your somewhere...
# 2602  As far as the service goes, the waitresses wer...
# ...                                                 ...
# 1903                         Its worth the wait though.
# 2262     Saul is pretty good, but definitely not great.
# 666   The food was very good, a great deal, and the ...
# 2441  The vibe is very relaxed and cozy, service was...
# 1140  I would like to return and try some of the oth...
#
#                    pred_category
# 453   (anecdotes/miscellaneous,)
# 1611                 (ambience,)
# 2078  (anecdotes/miscellaneous,)
# 2715  (anecdotes/miscellaneous,)
# 2602                  (service,)
# ...                          ...
# 1903  (anecdotes/miscellaneous,)
# 2262  (anecdotes/miscellaneous,)
# 666                      (food,)
# 2441             (food, service)
# 1140  (anecdotes/miscellaneous,)
#
# [761 rows x 2 columns]

# %%
pred_df.to_csv('pred_df.csv',index=False)

# %% [markdown]
# ### Sentiment Analysis

# %%
# Loading positive and negative words

neg_file = open("neg_words.txt", encoding = "ISO-8859-1")
pos_file = open("pos_words.txt", encoding = "ISO-8859-1")

neg = [line.strip() for line in neg_file.readlines()] # Readlines returns a list of the lines in the file
pos = [line.strip() for line in pos_file.readlines()]

opinion_words = neg + pos

# Run below code only if running for the first time

# Word2Vec consists of models for generating word embedding. 
# Words that occur in similar context tend to be closer to each other in vector space


 
# glove_input_file = 'glove.6B.100d.txt' # A pre-trained model for sentiment analysis #comment this after running once

glove_vec_file = "glove.6B.100d.txt.word2vec" 
word2vec = gensim.models.KeyedVectors.load_word2vec_format(glove_vec_file, binary= False)
# KeyedVectors:  a mapping between keys and vectors.

pickle.dump(word2vec, open("word2vec_glove.pkl", "wb"))
    
# load above saved word embedding
word2vec = pickle.load(open("word2vec_glove.pkl", "rb"))

# load the multi label binarizer from the aspect model that we've build above
mlb = pickle.load(open("mlb.pkl", "rb"))

# load the fitted Naive Bayes Model
naive_model1 = pickle.load(open("naive_model1.pkl", "rb"))

# %%
# Classes in Multi Label Binarizer
mlb.classes_
# Out:
# array(['ambience', 'anecdotes/miscellaneous', 'food', 'price', 'service'],
#       dtype=object)

# %%
def check_similarity(aspects, word):
    # checks for similarity between the aspect and given word and returns the most similar aspect for the given word
    similarity = []
    for aspect in aspects:
        similarity.append(word2vec.n_similarity([aspect], [word]))
        
        # setting threshold for maximum similarity
    if max(similarity) > 0.18:
        return aspects[np.argmax(similarity)] # Returns the indices of the maximum value
    else:
        return None
    
    
def assign_term_to_aspect(aspect_sent, terms_dict, sent_dict, pred):
    
    # This function takes in a Sentiment dictionary and appends the aspect dictionary 
    # aspect_sent: Total sentiment tally
    # terms_dict: Dictionary with individual aspects and their associated sentiments
    # sent_dict: Counter of the form : Counter(term: sentiment score)
    # returns two types of aspect dictionaries: updated terms_dict and aspect_sent
    
    aspects = ["ambience", "food", "price", "service"]
    
    # checking word2vec
    
    for term in sent_dict:
        try:
            
            if check_similarity(aspects, term.split()[-1]): # use .split() because word2vec can't process Compund Nouns
                terms_dict[check_similarity(aspects, term.split()[-1])][term] += sent_dict[term]
#                 sent_dict[term]
                if sent_dict[term] > 0:
                    aspect_sent[check_similarity(aspects, term.split)]["pos"] += sent_dict[term]
                else:
                    aspect_sent[check_similarity(aspects, term.split)]["neg"] += abs(sent_dict[term])
            elif(pred[0] ==  "anecdotes/miscellaneous"):
                continue
            elif(len(pred) == 1):
                terms_dict[pred[0]][term] += sent_dict[term]
#                 sent_dict[term]
                if sent_dict[term] > 0:
                    aspect_sent[pred[0]]["pos"] += sent_dict[term]
                else:
                    aspect_sent[pred[0]]["neg"] += abs(sent_dict[term])
                    
            # if unable to classify then put it in miscellaneous bucket
            
            else:
                terms_dict["misc"][term] += sent_dict[term]
#                 sent_dict[term]
                if sent_dict[term] > 0:
                    aspect_sent["misc"]["pos"] += sent_dict[term]
                else:
                    aspect_sent["misc"]["neg"] += abs(sent_dict[term])
                    
        except:
#             print(term, "Not in vocab")
            continue
    return aspect_sent, terms_dict


def feature_sentiment(sentence):
    # input: dictionary and sentence
    # this function appends dictionary with new features if features didn't exist previously then updates sentiments
    # to each of the new and oexistingld features
    # returns updated dictionary
    
    sent_dict = Counter()
    sentence = nlp(sentence)
    debug = 0
    for token in sentence:
        # check if word is an opinion word then assign a sentiment
        if token.text in opinion_words:
            sentiment = 1 if token.text in pos else -1
            # if target is an adverb modifier (eg: pretty, highly, etc.) but also an opinion word, ignore and pass
            if token.dep_ == "advmod":
                continue
            elif token.dep_ == "amod": # opinion words that are adjectives, verbs, adverbs, etc.
                sent_dict[token.head.text] += sentiment
                
            else:
                for child in token.children:
                    #  It checks for child tokens for each adjective and picks up the adverbs
                    # if there is an adjective modifier (eg: pretty, very, etc.), then add more weight to sentiment
                    if((child.dep_ == "amod") or (child.dep_ == "advmod")) and (child.text in opinion_words):
                        sentiment *= 1.5
                    # add negative sentiment for negative words
                    if child.dep_ == "neg":
                        sentiment *= -1
                    
                for child in token.children:
                    # if it's a verb then check if it's a direct object
                    # direct object is the noun or noun phrase that's receiving the action of the verb
                    if (token.pos_ == "VERB") & (child.dep_ == "dobj"):
                        sent_dict[child.text] += sentiment
                    
                        # check for conjugates (both a and b) and add them to dictionary
                        subchildren = []
                        conj = 0
                        for subchild in child.children:
                            if subchild.text == "and":
                                conj = 1
                            if (conj == 1) and (subchild.text != "and"):
                                subchildren.append(subchild.text)
                                conj = 0
                        for subchild in subchildren:
                            sent_dict[subchild] += sentiment
                            
                # check for negation
                for child in token.head.children:
                    noun = ""
                    if ((child.dep_ == "amod") or (child.dep_ == "advmod")) and (child.text in opinion_words):
                        sentiment *= 1.5
                    # check for negation words and flip the sign of sentiment
                    if (child.dep_ == "neg"): 
                        sentiment *= -1
                        
                # check for nouns
                for child in token.head.children:
                    noun = ""
                    if (child.pos_ == "NOUN") and (child.text not in sent_dict):
                        noun = child.text
                        # Also, check for compound nouns
                        for subchild in child.children:
                            if subchild.dep_ == "compound":
                                noun = subchild.text + " " + noun
                        sent_dict[noun] += sentiment
                    debug += 1
                
    return sent_dict

def classify_and_sent(sentence, aspect_sent, terms_dict):
    # classifies the sentence into a category and assign a sentiment
    # aspect_dict: parent dictionary with all aspects
    # input the sentence and aspect dictionary which is going to be updated
    # output will be the updated aspect dictionary
    
    # classify the sentence using NB Classifier
    predicted = naive_model1.predict([sentence])
    pred = mlb.inverse_transform(predicted)
#     print(pred)
    # this will take your labels and transform them back to the classes with the encoding. 
    
    # get aspect names and repective sentiments in dictionary form
    sent_dict = feature_sentiment(sentence)
    
    # categorize the aspect names into given 4 aspects in aspect_dict
    aspect_sent, terms_dict = assign_term_to_aspect(aspect_sent, terms_dict, sent_dict, pred[0])
    return aspect_sent, terms_dict

# def replace_pronouns(text):
#     coref.one_shot_coref(text)
#     return coref.get_resolved_utterances()[0]



def split_sentence(text):
    # splits review into list of sentences using spacy's sentence parser
    
    review = nlp(text)
#     print(review)
    bag_sentence = []
    start = 0
    for token in review:
#         print(token) # words
#         print(token.i)
        if token.sent_start == 1:
#             print(token)
            bag_sentence.append(review[start: (token.i-1)])
            start = token.i # index
#             print(bag_sentence)
#             print("a")
            
        if token.i == len(review)-1:
            bag_sentence.append(review[start: (token.i+1)])
#             print("b")
#         print(bag_sentence)
    return bag_sentence

# remove special characters using regex
def remove_special_char(sentence):
    return re.sub(r"[^a-zA-Z0-9.',:;?]+", " ", sentence)

def review_pipe(review, aspect_sent, terms_dict= {"ambience": Counter(), "food": Counter(), "price": Counter(), 
                                                  "service": Counter(), "misc": Counter()}):
#     review = replace_pronouns(review)
    sentences = split_sentence(review)
#     print(sentences)
    for sentence in sentences:
        sentence = remove_special_char(str(sentence))
#         print("Sentences:", sentences)
#         print("Review:", review)
        aspect_sent, terms_dict = classify_and_sent(sentence.lower(), aspect_sent, terms_dict)
    return aspect_sent, terms_dict

# %% [markdown]
# #### Test Codes

# %%
# test code for feature_sentiment

# test1
# sentence = "As far as the service goes, the waitresses were not particularly friendly, but they got the job done."
sentence = "I came here with my friends on a Tuesday night. The sushi here is amazing. Our waiter was very helpful, but the music was terrible."
feature_sentiment(sentence)
# Out:
# Counter({'sushi': 1, 'waiter': 1, 'music': -1})

# %%
# test2

sentence= "This is place is in the bottom 1% of my Chinese food experiences.  The atmosphere in the restaurant is creepy and the food tastes bad."
feature_sentiment(sentence)
# Out:
# Counter({'atmosphere': -1, 'food': -1})

# %%
# test case1
terms_dict = {"ambience": Counter(), "food": Counter(), "price": Counter(), "service": Counter(), "misc": Counter()}
aspect_sent = {"ambience": Counter(), "food": Counter(), "price": Counter(), "service": Counter(), "misc": Counter()}
review = "This is place is in the bottom 1% of my Chinese food experiences.  The atmosphere in the restaurant is creepy and the food tastes bad."
review_pipe(review, aspect_sent, terms_dict)
# Out:
# ({'ambience': Counter(),
#   'food': Counter(),
#   'price': Counter(),
#   'service': Counter(),
#   'misc': Counter()},
#  {'ambience': Counter({'atmosphere': 1}),
#   'food': Counter({'food': 1}),
#   'price': Counter(),
#   'service': Counter(),
#   'misc': Counter()})

# %%
# test case 2
test1={'ambience':Counter(), 'food':Counter(), 'price':Counter(), 'service':Counter(),'misc':Counter()}
test2={'ambience':Counter(), 'food':Counter(), 'price':Counter(), 'service':Counter(),'misc':Counter()}
# review = "top notch"
review = "This place is amazing.  I love the food and the staff, everybody is so nice especially the owner. The food is fresh and very good quality."
review_pipe(review, test1, test2)
# Out:
# ({'ambience': Counter(),
#   'food': Counter(),
#   'price': Counter(),
#   'service': Counter(),
#   'misc': Counter()},
#  {'ambience': Counter(),
#   'food': Counter({'food': 2, 'quality': 1}),
#   'price': Counter({'owner': 1}),
#   'service': Counter({'place': 1, 'staff': 1}),
#   'misc': Counter()})

# %%
# split_sentence("top notch")
split_sentence("I came here with my friends on a Tuesday night. The sushi here is amazing. Our waiter was very helpful, but the music was terrible.")
# Out:
# [I came here with my friends on a Tuesday night,
#  The sushi here is amazing,
#  Our waiter was very helpful, but the music was terrible.]

# %%
# use the word embeddings from word2vec to supplement the Naive Bayes Categorization of Aspects

# word2vec.n_similarity(["food"], ["sushi"]) # similarity b/w 2 terms

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Chief\\Documents\\Praxis\\Capstone Project\\Notebooks\\threshold'

# %% [markdown]
# ### Restaurant Ratings

# %%
# for 1 lakh reviews
dataset = pd.read_csv("cleaned_reviews.csv")

# %%
# os.getcwd()

# %%
def scoringFunc(ratingsDict):
    if(ratingsDict['pos']+ratingsDict['neg'] == 0.0):
        return 0.0
    else:
        return (ratingsDict['pos']/(ratingsDict['pos']+ratingsDict['neg']))*5.0

restaurant_ratings = pd.DataFrame(columns=['restaurant','food_ratings','service_ratings','ambience_ratings','price_ratings',
                                           'misc_ratings'])

for res_id in dataset["business_id"].unique():
    
    terms_dict = {'ambience':Counter(), 'food':Counter(), 'price':Counter(), 'service':Counter(),'misc':Counter()}
    aspect_sent = {'ambience':Counter(), 'food':Counter(), 'price':Counter(), 'service':Counter(),'misc':Counter()}
    
    for review in dataset[dataset["business_id"] == res_id]["text"]:
        aspect_sent, terms_dict = review_pipe(review, aspect_sent, terms_dict)
    
    restaurant_ratings = restaurant_ratings.append({"restaurant" : res_id,
                                                    "food_ratings" : scoringFunc(aspect_sent['food']),
                                                    "service_ratings" : scoringFunc(aspect_sent['service']),
                                                    "ambience_ratings" : scoringFunc(aspect_sent['ambience']),
                                                    "price_ratings" : scoringFunc(aspect_sent['price'])
                                                    },ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-d359d42fae2e> in <module>
#      14
#      15     for review in dataset[dataset["business_id"] == res_id]["text"]:
# ---> 16         aspect_sent, terms_dict = review_pipe(review, aspect_sent, terms_dict)
#      17
#      18     restaurant_ratings = restaurant_ratings.append({"restaurant" : res_id,
#
# <ipython-input-15-9e34ad533324> in review_pipe(review, aspect_sent, terms_dict)
#     191 #         print("Sentences:", sentences)
#     192 #         print("Review:", review)
# --> 193         aspect_sent, terms_dict = classify_and_sent(sentence.lower(), aspect_sent, terms_dict)
#     194     return aspect_sent, terms_dict
#     195
#
# <ipython-input-15-9e34ad533324> in classify_and_sent(sentence, aspect_sent, terms_dict)
#     143
#     144     # get aspect names and repective sentiments in dictionary form
# --> 145     sent_dict = feature_sentiment(sentence)
#     146
#     147     # categorize the aspect names into given 4 aspects in aspect_dict
#
# <ipython-input-15-9e34ad533324> in feature_sentiment(sentence)
#      67
#      68     sent_dict = Counter()
# ---> 69     sentence = nlp(sentence)
#      70     debug = 0
#      71     for token in sentence:
#
# ~\anaconda3\lib\site-packages\spacy\language.py in __call__(self, text, disable, component_cfg)
#     988                 error_handler = proc.get_error_handler()
#     989             try:
# --> 990                 doc = proc(doc, **component_cfg.get(name, {}))
#     991             except KeyError as e:
#     992                 # This typically happens if a component is not initialized
#
# ~\anaconda3\lib\site-packages\spacy\pipeline\trainable_pipe.pyx in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# ~\anaconda3\lib\site-packages\spacy\pipeline\tagger.pyx in spacy.pipeline.tagger.Tagger.predict()
#
# ~\anaconda3\lib\site-packages\thinc\model.py in predict(self, X)
#     310         only the output, instead of the `(output, callback)` tuple.
#     311         """
# --> 312         return self._func(self, X, is_train=False)[0]
#     313
#     314     def finish_update(self, optimizer: Optimizer) -> None:
#
# ~\anaconda3\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~\anaconda3\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~\anaconda3\lib\site-packages\thinc\layers\with_array.py in forward(model, Xseq, is_train)
#      38         return model.layers[0](Xseq, is_train)
#      39     else:
# ---> 40         return _list_forward(cast(Model[List2d, List2d], model), Xseq, is_train)
#      41
#      42
#
# ~\anaconda3\lib\site-packages\thinc\layers\with_array.py in _list_forward(model, Xs, is_train)
#      74     lengths = layer.ops.asarray1i([len(seq) for seq in Xs])
#      75     Xf = layer.ops.flatten(Xs, pad=pad)  # type: ignore
# ---> 76     Yf, get_dXf = layer(Xf, is_train)
#      77
#      78     def backprop(dYs: List2d) -> List2d:
#
# ~\anaconda3\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~\anaconda3\lib\site-packages\thinc\layers\softmax.py in forward(model, X, is_train)
#      32     W = cast(Floats2d, model.get_param("W"))
#      33     b = cast(Floats1d, model.get_param("b"))
# ---> 34     Y = model.ops.affine(X, W, b)
#      35     Y = model.ops.softmax(Y)
#      36
#
# ~\anaconda3\lib\site-packages\thinc\backends\ops.py in affine(self, X, W, b)
#     204         Y = X @ W.T + b
#     205         """
# --> 206         Y = self.gemm(X, W, trans2=True)
#     207         Y += b
#     208         return Y
#
# KeyboardInterrupt:

# %% [markdown]
# ### User weights

# %%
def scoringFunc(ratingsDict):
    if(ratingsDict['pos']+ratingsDict['neg'] == 0.0):
        return 0.0
    else:
        return (ratingsDict['pos']/(ratingsDict['pos']+ratingsDict['neg']))*100.0


user_weights = pd.DataFrame(columns=['user','food_weight','service_weight','ambience_weight','price_weight'
                                          ,'misc_weight'])

for user_id in dataset["user_id"].unique():
    
    terms_dict = {'ambience':Counter(), 'food':Counter(), 'price':Counter(), 'service':Counter(),'misc':Counter()}
    aspect_sent = {'ambience':Counter(), 'food':Counter(), 'price':Counter(), 'service':Counter(),'misc':Counter()}
    
    for review in dataset[dataset["user_id"] == user_id]["text"]:
        aspect_sent, terms_dict = review_pipe(review, aspect_sent, terms_dict)
    
    user_weights = user_weights.append({"user" : user_id,
                                                    "food_weight" : scoringFunc(aspect_sent['food']),
                                                    "service_weight" : scoringFunc(aspect_sent['service']),
                                                    "ambience_weight" : scoringFunc(aspect_sent['ambience']),
                                                    "price_weight" : scoringFunc(aspect_sent['price']),
                                                    "misc_weight" : scoringFunc(aspect_sent['misc'])
                                                    },ignore_index=True)
    
    
user_weights['Total'] = user_weights['food_weight'] + user_weights['service_weight'] + user_weights['ambience_weight'] + user_weights['price_weight']
user_weights['food_weight'] = round((user_weights['food_weight']/user_weights['Total']) * 100,2)
user_weights['service_weight'] = round((user_weights['service_weight']/user_weights['Total']) * 100,2)
user_weights['ambience_weight'] = round((user_weights['ambience_weight']/user_weights['Total']) * 100,2)
user_weights['price_weight'] = round((user_weights['price_weight']/user_weights['Total']) * 100,2)
del user_weights['Total']

# %%
user_weights.to_csv('user_weights_16052021_0.18.csv',index=False)

# %%
def scoringFunc(ratingsDict):
    if(ratingsDict['pos']+ratingsDict['neg'] == 0.0):
        return 0.0
    else:
        return (ratingsDict['pos']/(ratingsDict['pos']+ratingsDict['neg']))*100.0


user_weights = pd.DataFrame(columns=['user','food_weight','service_weight','ambience_weight','price_weight'
                                          ,'misc_weight'])

for user_id in dataset["user"].unique():
    
    terms_dict = {'ambience':Counter(), 'food':Counter(), 'price':Counter(), 'service':Counter(),'misc':Counter()}
    aspect_sent = {'ambience':Counter(), 'food':Counter(), 'price':Counter(), 'service':Counter(),'misc':Counter()}
    
    for review in dataset[dataset["user"] == user_id]["text"]:
        aspect_sent, terms_dict = review_pipe(review, aspect_sent, terms_dict)
    
    user_weights = user_weights.append({"user" : user_id,
                                                    "food_weight" : scoringFunc(aspect_sent['food']),
                                                    "service_weight" : scoringFunc(aspect_sent['service']),
                                                    "ambience_weight" : scoringFunc(aspect_sent['ambience']),
                                                    "price_weight" : scoringFunc(aspect_sent['price']),
                                                    "misc_weight" : scoringFunc(aspect_sent['misc'])
                                                    },ignore_index=True)
    
    
user_weights['Total'] = user_weights['food_weight'] + user_weights['service_weight'] + user_weights['ambience_weight'] + user_weights['price_weight']
user_weights['food'] = round((user_weights['food_weight']/user_weights['Total']) * 100,2)
user_weights['service'] = round((user_weights['service_weight']/user_weights['Total']) * 100,2)
user_weights['ambience_weight'] = round((user_weights['ambience_weight']/user_weights['Total']) * 100,2)
user_weights['price_weight'] = round((user_weights['price_weight']/user_weights['Total']) * 100,2)
del user_weights['Total']

# %% [markdown]
# ### Aspect Dictionary and User Weights

# %%
# To get Sorted Aspect Dictionary and User Weights

aspectDictionary = {"ambience":{},"food":{},"price":{},"service":{},"misc":{}}
sorted_aspectDictionary = {"ambience":{},"food":{},"price":{},"service":{},"misc":{}}
user_weights = pd.DataFrame(columns=['user','food_weight','service_weight','ambience_weight','price_weight'])

def scoringFunc(ratingsDict):
    total = 0.0
    total = total + ratingsDict['pos'] + ratingsDict['neg']
    return round(total, 2)

def addToDictionary(terms_dict):
    aspects = list(aspectDictionary.keys())
    for aspect in aspects:
        for word in list(terms_dict[aspect].keys()):
            if word not in list(aspectDictionary[aspect].keys()):
                aspectDictionary[aspect][word] = terms_dict[aspect][word]
            else:
                aspectDictionary[aspect][word] += terms_dict[aspect][word]

for user_id in dataset["user_id"].unique():
    
    terms_dict = {'ambience':Counter(), 'food':Counter(), 'price':Counter(), 'service':Counter(),'misc':Counter()}
    aspect_sent = {'ambience':Counter(), 'food':Counter(), 'price':Counter(), 'service':Counter(),'misc':Counter()}
    
    for review in dataset[dataset["user_id"] == user_id]["text"]:
        aspect_sent, terms_dict = review_pipe(review, aspect_sent, terms_dict)
    
    user_weights = user_weights.append({"user" : user_id,
                                                    "food_weight" : scoringFunc(aspect_sent['food']),
                                                    "service_weight" : scoringFunc(aspect_sent['service']),
                                                    "ambience_weight" : scoringFunc(aspect_sent['ambience']),
                                                    "price_weight" : scoringFunc(aspect_sent['price'])
                                                    },ignore_index=True)
    addToDictionary(terms_dict)

for aspect in list(sorted_aspectDictionary.keys()):
    sorted_aspectDictionary[aspect] = dict(sorted(aspectDictionary[aspect].items(),key = lambda item: item[1],reverse= True))
    
user_weights['Total'] = user_weights['food_weight'] + user_weights['service_weight'] + user_weights['ambience_weight'] + user_weights['price_weight']
user_weights['food_weight'] = round((user_weights['food_weight']/user_weights['Total']) * 100,2)
user_weights['service_weight'] = round((user_weights['service_weight']/user_weights['Total']) * 100,2)
user_weights['ambience_weight'] = round((user_weights['ambience_weight']/user_weights['Total']) * 100,2)
user_weights['price_weight'] = round((user_weights['price_weight']/user_weights['Total']) * 100,2)
del user_weights['Total']

user_weights.to_csv('user_weights_15052021_0.30.csv',index=False)

import pickle
f = open("sorted_aspectDictionary.pkl","wb")
pickle.dump(sorted_aspectDictionary,f)
f.close()

# %%
user_weights2 = pd.read_pickle("sorted_aspectDictionary.pkl")
user_weights2_df = pd.DataFrame.from_dict(user_weights2)
user_weights2_df.to_csv("dictionary_0.3_dictionary.csv")
user_weights2
# Out:
# {'ambience': {'atmosphere': 5935,
#   'flavor': 2875,
#   'fun': 1896,
#   'flavors': 1837,
#   'decor': 1808,
#   'ambiance': 1747,
#   'seating': 1461,
#   'vibe': 1438,
#   'perfection': 1070,
#   'texture': 1069,
#   'brunch': 887,
#   'hype': 873,
#   'ambience': 827,
#   'cafe': 684,
#   'sweetness': 606,
#   'delight': 526,
#   'mess': 510,
#   'smell': 504,
#   'noise': 479,
#   'lighting': 459,
#   'patio': 458,
#   'pleasure': 361,
#   'liking': 356,
#   'style': 317,
#   'charm': 293,
#   'diner': 266,
#   'blend': 266,
#   'feeling': 265,
#   'quaint': 263,
#   'brew': 259,
#   'consistency': 244,
#   'bathrooms': 230,
#   'layout': 208,
#   'chewy': 208,
#   'vibes': 205,
#   'mood': 185,
#   'spicy': 182,
#   'hassle': 177,
#   'seasoning': 173,
#   'amuse': 165,
#   'cheesy': 163,
#   'cleanliness': 160,
#   'richness': 160,
#   'bland': 155,
#   'impression': 154,
#   'chill': 148,
#   'quieter': 147,
#   'tastes': 140,
#   'sense': 138,
#   'ale': 137,
#   'warmth': 129,
#   'crowd': 127,
#   'excitement': 123,
#   'gran gusto': 115,
#   'casual': 115,
#   'hole': 112,
#   'humor': 111,
#   'sound': 107,
#   'novelty': 105,
#   'friendliness': 102,
#   'wifi': 100,
#   'acoustics': 95,
#   'oasis': 95,
#   'stars': 94,
#   'mocha': 93,
#   'flair': 91,
#   'fireplace': 91,
#   'palate': 88,
#   'exterior': 86,
#   'brews': 85,
#   'colors': 85,
#   'aftertaste': 84,
#   'slaw': 82,
#   'enjoyment': 80,
#   'snob': 78,
#   'accompaniment': 78,
#   'bitterness': 76,
#   '  atmosphere': 72,
#   'upscale': 72,
#   'buttery': 71,
#   'aspect': 71,
#   'theme': 71,
#   'attentive': 70,
#   'concoction': 69,
#   'ish': 69,
#   'coleslaw': 69,
#   'clientele': 67,
#   'hospitality': 67,
#   'mediocrity': 65,
#   'smells': 64,
#   'bartenders': 63,
#   'freshness': 63,
#   'eatery': 61,
#   'aroma': 59,
#   'creations': 58,
#   'descriptions': 58,
#   'textures': 57,
#   'sorbet': 56,
#   'creativity': 55,
#   'caramel': 55,
#   'exaggeration': 55,
#   'walls': 54,
#   'cafes': 54,
#   'hipster': 53,
#   'pub': 52,
#   'attraction': 52,
#   'condiments': 51,
#   'foodie': 51,
#   'booths': 51,
#   'tenderness': 51,
#   'breakfasts': 51,
#   'border cafe': 49,
#   'tunes': 47,
#   'frills': 47,
#   'touches': 47,
#   'obsession': 47,
#   'fancy': 47,
#   'refreshing': 46,
#   'hip': 46,
#   'odor': 46,
#   'tiramisu': 46,
#   'gooey': 45,
#   'flavours': 45,
#   'pint': 45,
#   'artwork': 44,
#   'savory': 43,
#   'hangout': 42,
#   'classy': 42,
#   'spiciness': 42,
#   'martinis': 42,
#   'snarky': 41,
#   'aesthetic': 41,
#   'indulgence': 40,
#   'accent': 40,
#   'respite': 40,
#   'cozy': 40,
#   'gusto': 40,
#   'restrooms': 40,
#   'flavour': 40,
#   'eateries': 39,
#   'coffee snob': 38,
#   'decorations': 38,
#   'salty': 38,
#   'interiors': 38,
#   'intimacy': 38,
#   'palette': 37,
#   'spaces': 37,
#   'chow fun': 37,
#   'concoctions': 37,
#   'chewiness': 36,
#   'awe': 36,
#   'lounge': 35,
#   'flavorful': 35,
#   '  ambiance': 34,
#   'pubs': 34,
#   'pretense': 34,
#   'harmony': 33,
#   'roomy': 33,
#   'tangy': 32,
#   'noir': 32,
#   'elegance': 32,
#   'cliche': 32,
#   'chatter': 32,
#   'madness': 32,
#   'homey': 32,
#   'celebratory': 32,
#   'delicacy': 32,
#   'hell': 32,
#   'creamy': 31,
#   'beer snob': 31,
#   'sampler': 31,
#   'food snob': 31,
#   'complexity': 31,
#   'masterpiece': 30,
#   'ramen': 30,
#   'cole slaw': 30,
#   '  seating': 30,
#   'surroundings': 30,
#   'sunday brunch': 29,
#   'couches': 29,
#   'complements': 29,
#   'pros': 29,
#   'conversations': 28,
#   'chic': 28,
#   'waiter': 28,
#   'satisfying': 28,
#   'welcoming': 28,
#   'saltiness': 27,
#   'jazz': 27,
#   'ladies': 27,
#   'garage': 27,
#   'plates': 27,
#   'breeze': 27,
#   'downstairs': 27,
#   'cajun': 26,
#   'politeness': 26,
#   'cool': 26,
#   'ideal': 26,
#   'decoration': 26,
#   'amenities': 26,
#   'bartender': 25,
#   'funky': 25,
#   'simplicity': 25,
#   'signage': 25,
#   'qualities': 25,
#   'fruity': 25,
#   'demeanor': 25,
#   'dark': 24,
#   'fault': 24,
#   'bands': 24,
#   'originality': 24,
#   'manners': 24,
#   'karaoke': 24,
#   'cellar': 23,
#   'decadence': 23,
#   'disdain': 23,
#   'scent': 23,
#   'pizza snob': 23,
#   'glow': 23,
#   'waitstaff': 23,
#   'punk': 22,
#   'floors': 22,
#   'props': 22,
#   'creaminess': 22,
#   'styles': 22,
#   'cor': 22,
#   'accents': 21,
#   'crunchy': 21,
#   'lit': 21,
#   'cuisines': 21,
#   '  brunch': 21,
#   'banter': 21,
#   'irony': 21,
#   'morsel': 21,
#   'mixes': 21,
#   'bummer': 21,
#   'acidity': 20,
#   'geeky': 20,
#   'greasy': 20,
#   'sounds': 20,
#   'bistro': 20,
#   'perk': 20,
#   'tepid': 20,
#   'fruit delight': 20,
#   'fi': 19,
#   'basement': 19,
#   'pricey': 19,
#   'thoughtfulness': 19,
#   'tub': 19,
#   'comfortable': 18,
#   'thrill': 18,
#   'band': 18,
#   'songs': 18,
#   'blends': 18,
#   'smokiness': 18,
#   'courtyard': 18,
#   'upstairs': 18,
#   'proximity': 18,
#   'revival': 18,
#   'waitress': 18,
#   'crispness': 17,
#   'character': 17,
#   'blah': 17,
#   'gumbo': 17,
#   'folk': 17,
#   'jukebox': 17,
#   'shade': 17,
#   'imitation': 16,
#   'refinement': 16,
#   'distracting': 16,
#   'playing': 16,
#   'paintings': 16,
#   'rock': 16,
#   'airy': 16,
#   'condescending': 15,
#   'sweaty': 15,
#   'polite': 15,
#   'awkwardness': 15,
#   'craziness': 15,
#   'dirty': 15,
#   'chaos': 15,
#   'nooks': 15,
#   'smelling': 15,
#   'fashioned': 15,
#   'aesthetics': 15,
#   'crap': 14,
#   'stranger': 14,
#   'tanks': 14,
#   'essence': 14,
#   'aromas': 14,
#   'calm': 14,
#   'deco': 14,
#   'shit': 14,
#   'sucker': 14,
#   'cons': 14,
#   'drawback': 14,
#   'coast cafe': 14,
#   'flavored': 14,
#   'woods': 13,
#   'ghetto': 13,
#   'euphoria': 13,
#   'condiment': 13,
#   'idiots': 13,
#   'baristas': 13,
#   'settings': 13,
#   'ceilings': 13,
#   'nightmare': 13,
#   'kid': 13,
#   'lady': 13,
#   'benches': 13,
#   'stools': 13,
#   'mural': 13,
#   'cosy': 13,
#   'accommodations': 13,
#   'cup': 12,
#   'nook': 12,
#   'fascination': 12,
#   'hostess': 12,
#   'appetizer sampler': 12,
#   'locale': 12,
#   'hipsters': 12,
#   'coffeehouse': 12,
#   'sensations': 12,
#   'trendy': 12,
#   'shame': 12,
#   'stroll': 12,
#   'backdrop': 12,
#   'den': 12,
#   'softness': 12,
#   'watery': 12,
#   'weird': 12,
#   'accoutrements': 12,
#   'gripe': 12,
#   '  ambience': 12,
#   'rooftop': 12,
#   'quiet': 12,
#   'posters': 12,
#   'messes': 12,
#   'saucy': 12,
#   'condescension': 12,
#   'peppery': 12,
#   'haunts': 12,
#   'gem': 11,
#   'latte': 11,
#   'brick': 11,
#   'rustic': 11,
#   'kitsch': 11,
#   'tranquil': 11,
#   'humid': 11,
#   'terrace': 11,
#   'pleasures': 11,
#   'tartness': 11,
#   'hearty': 11,
#   'supper': 11,
#   'furnishings': 11,
#   'fondness': 11,
#   'sarcasm': 11,
#   'fixtures': 11,
#   'overkill': 11,
#   'scenery': 11,
#   'desert': 10,
#   'comfy': 10,
#   'decadent': 10,
#   'hippie': 10,
#   'nostalgia': 10,
#   'esque': 10,
#   'restaurant decor': 10,
#   'surfaces': 10,
#   'lush': 10,
#   'bohemian': 10,
#   'videos': 10,
#   'tacos': 10,
#   'aura': 10,
#   'killer': 10,
#   'retro': 10,
#   'monstrosity': 10,
#   'bustle': 10,
#   'illusion': 10,
#   'chinatown': 10,
#   'greasy mess': 10,
#   'goodness': 10,
#   'gimmick': 10,
#   'shake': 10,
#   'waffles': 10,
#   'velvety': 10,
#   'nourishing': 10,
#   'dim': 10,
#   'pluses': 9,
#   'coziness': 9,
#   'grub': 9,
#   'gratification': 9,
#   'bowls': 9,
#   'characters': 9,
#   'background noise': 9,
#   'nightlife': 9,
#   'porch': 9,
#   'chock': 9,
#   'juiciness': 9,
#   'paneling': 9,
#   'authentic': 9,
#   'family style': 9,
#   'fish tanks': 9,
#   'overload': 9,
#   'jeans': 9,
#   'intrigue': 9,
#   'playlist': 9,
#   'mouthfeel': 9,
#   'oomph': 9,
#   'sights': 9,
#   'natured': 9,
#   'espresso': 9,
#   'unappealing': 9,
#   'etiquette': 9,
#   'aggravation': 9,
#   'corners': 9,
#   'loud': 9,
#   'understatement': 9,
#   'chocolate decadence': 9,
#   'negativity': 9,
#   'buzzing': 9,
#   'propaganda': 9,
#   'curiosity': 9,
#   'pleasant': 9,
#   'clarity': 9,
#   'pretentiousness': 9,
#   'displays': 8,
#   'waitresses': 8,
#   'thrills': 8,
#   'patio seating': 8,
#   'gimmicky': 8,
#   'parlor': 8,
#   'curtains': 8,
#   'winner': 8,
#   'decors': 8,
#   'preserves': 8,
#   'hair': 8,
#   'personable': 8,
#   'reflection': 8,
#   'intro': 8,
#   '  bathrooms': 8,
#   'waiters': 8,
#   'photos': 8,
#   'romantic': 8,
#   'lamps': 8,
#   'melding': 8,
#   'd': 8,
#   'contentment': 8,
#   'paradise': 8,
#   'counterpoint': 8,
#   'irritating': 8,
#   'gingerbread': 8,
#   'amenity': 8,
#   'weekend brunch': 8,
#   'sq': 8,
#   'yuppies': 8,
#   'afterthought': 8,
#   'evenings': 8,
#   'rapport': 8,
#   'wit': 8,
#   'serenity': 7,
#   'greenery': 7,
#   'margaritas': 7,
#   'boredom': 7,
#   'combo': 7,
#   'creme caramel': 7,
#   'sparkling': 7,
#   'coats': 7,
#   'country style': 7,
#   'tavern': 7,
#   'magic': 7,
#   'cider': 7,
#   'dungeon': 7,
#   'shades': 7,
#   'coffee flavor': 7,
#   'veggie mess': 7,
#   'schmancy': 7,
#   'sunlight': 7,
#   'rarity': 7,
#   'spiced': 7,
#   'motif': 7,
#   'flavorings': 7,
#   'citrusy': 7,
#   'attentiveness': 7,
#   'bit quieter': 7,
#   'candles': 7,
#   'sushi snob': 7,
#   'sourness': 7,
#   'nastiness': 7,
#   'landscape': 7,
#   'absurdity': 7,
#   'ambient': 7,
#   'decorating': 7,
#   'influences': 7,
#   'bartley': 7,
#   'unappetizing': 7,
#   'conscious': 7,
#   'inviting': 7,
#   'indoors': 7,
#   'manger': 7,
#   'shack': 7,
#   'imagination': 7,
#   'flare': 7,
#   'dense': 7,
#   'sunshine': 7,
#   'reminiscent': 7,
#   'bouncy': 7,
#   'pillows': 7,
#   'effortless': 7,
#   'suite': 7,
#   'oddity': 7,
#   'balcony': 7,
#   'quirky': 6,
#   'tones': 6,
#   'chai': 6,
#   'concise': 6,
#   'decorated': 6,
#   'earthiness': 6,
#   'hassles': 6,
#   'lobster tanks': 6,
#   'elbows': 6,
#   'comforting': 6,
#   'letdown': 6,
#   'charms': 6,
#   'chair': 6,
#   'headache': 6,
#   'glitz': 6,
#   'minimalist': 6,
#   'longing': 6,
#   'win': 6,
#   'pride': 6,
#   'grandeur': 6,
#   'awning': 6,
#   'tea flavor': 6,
#   'mice': 6,
#   'brightness': 6,
#   'funk': 6,
#   'decor ambiance': 6,
#   'bar seating': 6,
#   'cute': 6,
#   'oftentimes': 6,
#   'patience': 6,
#   'cave': 6,
#   'rugs': 6,
#   'apricot': 6,
#   'syrupy': 6,
#   'genre': 6,
#   'food bland': 6,
#   'fishy': 6,
#   'ginger ale': 6,
#   'musicians': 6,
#   'connoisseur': 6,
#   'ramen snob': 6,
#   'cacophony': 6,
#   'notch': 6,
#   'tablecloths': 6,
#   'customization': 6,
#   'drawbacks': 6,
#   'spacious': 6,
#   'commotion': 6,
#   'facade': 6,
#   'murals': 6,
#   'overcooked': 6,
#   'street noise': 6,
#   'dive': 6,
#   'dimmer': 6,
#   'vocabulary': 6,
#   'burritos': 6,
#   'towels': 6,
#   'wi': 6,
#   'caf': 6,
#   'craftsmanship': 6,
#   'tapas': 6,
#   'smoky': 6,
#   'sparkle': 6,
#   'frosting': 6,
#   'glasses': 6,
#   'confusion': 6,
#   'sneer': 6,
#   'graciousness': 6,
#   'barista': 5,
#   'pinot noir': 5,
#   'martini': 5,
#   'depression': 5,
#   'service attentive': 5,
#   'overview': 5,
#   'curry flavor': 5,
#   'chocolate orgy': 5,
#   'restroom': 5,
#   'lively': 5,
#   'selections': 5,
#   'ginger flavor': 5,
#   'guilt': 5,
#   'patios': 5,
#   'relaxed': 5,
#   'fogs': 5,
#   'relaxing': 5,
#   'lightness': 5,
#   'annoyance': 5,
#   'spicier': 5,
#   'lemon': 5,
#   'flickering': 5,
#   'din': 5,
#   'cabbage slaw': 5,
#   'retreat': 5,
#   'lemon flavor': 5,
#   'ac': 5,
#   'joy': 5,
#   'sharpness': 5,
#   'smoothness': 5,
#   'orgy': 5,
#   'luau': 5,
#   'refills': 5,
#   'soundtrack': 5,
#   'uniqueness': 5,
#   'mirrors': 5,
#   'crowds': 5,
#   'alley': 5,
#   'undertones': 5,
#   'lemonade': 5,
#   'bits': 5,
#   'spoon': 5,
#   'vermouth': 5,
#   'dj': 5,
#   'dope': 5,
#   'smiles': 5,
#   'seafood madness': 5,
#   'glossary': 5,
#   'epitome': 5,
#   'buzz': 5,
#   'chewier': 5,
#   'seatings': 5,
#   'lol': 5,
#   'accouterments': 5,
#   'ventilation': 5,
#   'backyard': 5,
#   'fragrance': 5,
#   'splendor': 5,
#   'hearth': 5,
#   'memories': 5,
#   'sober': 5,
#   'charlie': 5,
#   'storefront': 5,
#   'attire': 5,
#   'gorgeous': 5,
#   'impressions': 5,
#   'chandeliers': 5,
#   'blending': 5,
#   'gems': 5,
#   'seafood delight': 5,
#   'clover': 5,
#   'mouthwatering': 5,
#   'bugs': 5,
#   'sin': 5,
#   'sunny': 5,
#   'damper': 5,
#   'gooey mess': 5,
#   'dudes': 5,
#   'dancing': 5,
#   'overtones': 5,
#   'pedestrian': 5,
#   'mindset': 5,
#   'voices': 5,
#   'restaurant atmosphere': 5,
#   'artists': 5,
#   'slices': 5,
#   'tonight': 5,
#   'oreos': 5,
#   'riff': 5,
#   'nuance': 5,
#   'bagel snob': 5,
#   'nonsense': 5,
#   'juxtaposition': 5,
#   'allure': 5,
#   'wintry': 5,
#   'ave': 5,
#   'positives': 5,
#   'trivia': 5,
#   'heaviness': 5,
#   'pop': 5,
#   'waits': 5,
#   'undertone': 5,
#   'genius': 5,
#   'farmhouse': 5,
#   'downsides': 5,
#   'cuteness': 5,
#   'lizard lounge': 5,
#   'pistachio flavor': 5,
#   'environments': 5,
#   'plating': 5,
#   'cream flavors': 5,
#   'smug': 5,
#   'tourist attraction': 5,
#   'bar tenders': 4,
#   'stairs': 4,
#   'o': 4,
#   'castle': 4,
#   'eyes': 4,
#   'annoying': 4,
#   'corny': 4,
#   'loveliness': 4,
#   'mushy': 4,
#   'subtlety': 4,
#   'stove': 4,
#   'snobby': 4,
#   'joke': 4,
#   'yay': 4,
#   'cocktail snob': 4,
#   'uninspired': 4,
#   'platter': 4,
#   'carpeting': 4,
#   'panels': 4,
#   'fuck': 4,
#   'chocolate flavor': 4,
#   'tile': 4,
#   'burger snob': 4,
#   'smorgasbord': 4,
#   'elation': 4,
#   'passion': 4,
#   'fantasy': 4,
#   'subtle': 4,
#   'star attraction': 4,
#   'hug': 4,
#   'heaven': 4,
#   'bubbly': 4,
#   'hookah': 4,
#   'bitch': 4,
#   'basements': 4,
#   'freak': 4,
#   'cbc': 4,
#   'gripes': 4,
#   'summer shack': 4,
#   'flaw': 4,
#   'calmness': 4,
#   'bang': 4,
#   '  decor': 4,
#   'negatives': 4,
#   'drapes': 4,
#   'yelp hype': 4,
#   'cask': 4,
#   'photographs': 4,
#   'confection': 4,
#   'sunset': 4,
#   'coolness': 4,
#   'interplay': 4,
#   'reeks': 4,
#   'bump': 4,
#   'summery': 4,
#   'zesty': 4,
#   'affection': 4,
#   'mouse': 4,
#   'creepy': 4,
#   'seamless': 4,
#   'laughter': 4,
#   'meh': 4,
#   'wine snob': 4,
#   'melange': 4,
#   'suits': 4,
#   'interesting': 4,
#   'memorabilia': 4,
#   'myself': 4,
#   'elegant': 4,
#   'nutty': 4,
#   'personality': 4,
#   'glory': 4,
#   'darkness': 4,
#   'homage': 4,
#   'exuberance': 4,
#   'extravagance': 4,
#   'qualm': 4,
#   'delights': 4,
#   'vent': 4,
#   'song': 4,
#   'pizzazz': 4,
#   'spectacle': 4,
#   'wonders': 4,
#   'dingy': 4,
#   'rundown': 4,
#   'diner style': 4,
#   'magnificence': 4,
#   'hat': 4,
#   'sofas': 4,
#   'sofa': 4,
#   'toasty': 4,
#   'complimentary': 4,
#   'drunk': 4,
#   'hop': 4,
#   'trifle': 4,
#   'wall charm': 4,
#   'aperitif': 4,
#   'wasteland': 4,
#   'dank': 4,
#   'elbow': 4,
#   'downfall': 4,
#   'bench': 4,
#   'awful': 4,
#   'setups': 4,
#   'standout': 4,
#   'positivity': 4,
#   'puns': 4,
#   'pizazz': 4,
#   'clash': 4,
#   'fulfillment': 4,
#   'noisy': 4,
#   'silverware': 4,
#   'waffle': 4,
#   'accommodating': 4,
#   'smack': 4,
#   'neighborhood charm': 4,
#   'indoor': 4,
#   'dirt': 4,
#   'fan': 4,
#   'banquet': 4,
#   'tiles': 4,
#   'moods': 4,
#   'gracious': 4,
#   'rooftop patio': 4,
#   'veggie delight': 4,
#   'delicate': 4,
#   'chocolaty': 4,
#   'blandness': 4,
#   'fool': 4,
#   'bakery cafe': 4,
#   'shirts': 4,
#   'oysters': 4,
#   'sangria': 4,
#   'pretentious': 4,
#   'boyfriend': 4,
#   'synopsis': 4,
#   'indulgent': 4,
#   'music playing': 4,
#   'superb': 4,
#   'curtain': 4,
#   'fruit caramel': 3,
#   'coffeehouses': 3,
#   'tvs': 3,
#   'caramel indulgence': 3,
#   'hostesses': 3,
#   'cleansers': 3,
#   'offense': 3,
#   'nachos': 3,
#   'guinness': 3,
#   'harlow': 3,
#   'cosmopolitan': 3,
#   'ass': 3,
#   'hangouts': 3,
#   'fairness': 3,
#   'rumor': 3,
#   'throwback': 3,
#   'techno': 3,
#   'trepidation': 3,
#   'statue': 3,
#   'bagels': 3,
#   'moistness': 3,
#   'belly': 3,
#   'earthy': 3,
#   'gamy': 3,
#   'penguins': 3,
#   'plough stars': 3,
#   'god': 3,
#   '  cleanliness': 3,
#   'lover': 3,
#   'char': 3,
#   'inventive': 3,
#   'exciting': 3,
#   'malty': 3,
#   'penchant': 3,
#   'music lover': 3,
#   'smelly': 3,
#   'yolk': 3,
#   'couples': 3,
#   'summer breeze': 3,
#   'world charm': 3,
#   'snappy': 3,
#   'dessert snob': 3,
#   'qualms': 3,
#   'vintage': 3,
#   'yellow': 3,
#   'ethos': 3,
#   'plush': 3,
#   'emptiness': 3,
#   'buddy': 3,
#   'imperfections': 3,
#   'themed': 3,
#   'grail': 3,
#   'fusion': 3,
#   'fun vibe': 3,
#   'believable': 3,
#   'smoothies': 3,
#   'bourbon ale': 3,
#   'libations': 3,
#   'getaway': 3,
#   'stool': 3,
#   'borderline': 3,
#   'boba': 3,
#   'pants': 3,
#   'brownie': 3,
#   'sidewalk seating': 3,
#   'upbringing': 3,
#   'insult': 3,
#   'injury': 3,
#   'body odor': 3,
#   'regularity': 3,
#   'harry': 3,
#   'inconsistency': 3,
#   'sparse': 3,
#   'ears': 3,
#   'd cor': 3,
#   'gloom': 3,
#   'heck': 3,
#   'breezy': 3,
#   'air conditioner': 3,
#   'cafe mocha': 3,
#   'semblance': 3,
#   'soothing': 3,
#   'sexy': 3,
#   'parking hassle': 3,
#   'poetic': 3,
#   'night fun': 3,
#   'scents': 3,
#   'delusions': 3,
#   'towel': 3,
#   'charming': 3,
#   'characteristic': 3,
#   'dude': 3,
#   'donuts': 3,
#   'refreshment': 3,
#   'atmosphere decor': 3,
#   'crema cafe': 3,
#   'bunch': 3,
#   'stylish': 3,
#   'tea snob': 3,
#   'gritty': 3,
#   'confines': 3,
#   'blessing': 3,
#   'style seating': 3,
#   'cheesiness': 3,
#   'groove': 3,
#   'booth seating': 3,
#   'restaurant layout': 3,
#   'parking garage': 3,
#   'stuffy': 3,
#   'wonderland': 3,
#   'lanterns': 3,
#   'carpets': 3,
#   'wrap': 3,
#   'nuances': 3,
#   'noises': 3,
#   'overbearing': 3,
#   'flaws': 3,
#   'pinball': 3,
#   'plough': 3,
#   'phrasing': 3,
#   'sweetheart': 3,
#   'menu descriptions': 3,
#   'buttery perfection': 3,
#   'y': 3,
#   'flowery': 3,
#   '  cons': 3,
#   'taco snob': 3,
#   'caper': 3,
#   'clouds': 3,
#   'shirt': 3,
#   'locks': 3,
#   'funny': 3,
#   'afternoons': 3,
#   'surrounds': 3,
#   'aisles': 3,
#   'fills': 3,
#   'crispy perfection': 3,
#   't shirts': 3,
#   'sewage smell': 3,
#   'lovely': 3,
#   'shui': 3,
#   'chocolate mocha': 3,
#   'neat': 3,
#   'asgard': 3,
#   'glistening': 3,
#   'elevators': 3,
#   'greek style': 3,
#   'chandelier': 3,
#   'merriment': 3,
#   'visual': 3,
#   'fireplaces': 3,
#   '  vibe': 3,
#   'pita': 3,
#   'alot': 3,
#   'lounges': 3,
#   'confusing': 3,
#   'fruity flavors': 3,
#   'hazard': 3,
#   'food atmosphere': 3,
#   'mentality': 3,
#   'environs': 3,
#   'colorful': 3,
#   'booze': 3,
#   'degrees': 3,
#   'cashier': 3,
#   'fun atmosphere': 3,
#   'sucks': 3,
#   'garlicky': 3,
#   ...},
#  'food': {'food': 33575,
#   'restaurant': 5193,
#   'meal': 4251,
#   'selection': 3301,
#   'menu': 3121,
#   'pizza': 3113,
#   'drinks': 2940,
#   'sauce': 2896,
#   'dish': 2886,
#   'people': 2793,
#   'variety': 2778,
#   'chicken': 2767,
#   'coffee': 2744,
#   'burger': 2614,
#   'fries': 2560,
#   'dishes': 2517,
#   'things': 2307,
#   'chocolate': 2270,
#   'bread': 2135,
#   'sandwich': 2076,
#   'love': 1990,
#   'beer': 1981,
#   'quality': 1905,
#   'problem': 1880,
#   'places': 1875,
#   'rice': 1785,
#   'taste': 1676,
#   'restaurants': 1591,
#   'burgers': 1541,
#   'noodles': 1527,
#   'greasy': 1508,
#   'meat': 1501,
#   'dinner': 1484,
#   'sandwiches': 1464,
#   'ingredients': 1462,
#   'sushi': 1412,
#   'fish': 1405,
#   'reviews': 1309,
#   'lemon': 1288,
#   'table': 1281,
#   'cocktails': 1277,
#   'soup': 1237,
#   'salad': 1235,
#   'something': 1202,
#   'them': 1187,
#   'broth': 1146,
#   'lack': 1131,
#   'cream': 1122,
#   'drink': 1100,
#   'ramen': 1036,
#   'potatoes': 1018,
#   'cheese': 1000,
#   'tea': 938,
#   'stuff': 925,
#   'lunch': 894,
#   'comfort': 872,
#   'pot': 862,
#   'meals': 847,
#   'egg': 835,
#   'pork': 822,
#   'room': 802,
#   'dessert': 767,
#   'items': 765,
#   'beef': 761,
#   'tables': 758,
#   'everything': 743,
#   'bowl': 738,
#   'environment': 699,
#   'eggs': 698,
#   'lobster': 697,
#   'recommendations': 695,
#   'crust': 685,
#   'pastries': 666,
#   'pig': 658,
#   'rolls': 643,
#   'breakfast': 643,
#   'wine': 640,
#   'mix': 625,
#   'shop': 623,
#   'seafood': 623,
#   'lamb': 609,
#   'desserts': 609,
#   'potato': 601,
#   'choices': 596,
#   'plate': 589,
#   'bite': 587,
#   'ones': 584,
#   'fat': 581,
#   'experiences': 576,
#   'cake': 566,
#   'water': 566,
#   'oysters': 557,
#   'steak': 556,
#   'dumplings': 551,
#   'bun': 539,
#   'pasta': 515,
#   'udon': 504,
#   'toast': 502,
#   'salads': 477,
#   'trouble': 467,
#   'curry': 466,
#   'favorite': 464,
#   'vegetables': 462,
#   'pan': 459,
#   'beer selection': 454,
#   'bomb': 453,
#   'margaritas': 447,
#   'goodness': 440,
#   'smoke': 427,
#   'salmon': 426,
#   'feel': 420,
#   'toppings': 420,
#   'chef': 417,
#   'veggies': 414,
#   'appetizers': 413,
#   'sauces': 410,
#   'kind': 406,
#   'appetizer': 401,
#   'shrimp': 400,
#   'foods': 398,
#   'jam': 397,
#   'cuisine': 387,
#   'buns': 381,
#   'plates': 379,
#   'cocktail': 376,
#   'tacos': 373,
#   'dining': 372,
#   'fatty': 372,
#   'bagels': 370,
#   'house': 365,
#   'fruit': 364,
#   'tofu': 347,
#   'salsa': 345,
#   'lots': 342,
#   'beans': 340,
#   'slices': 339,
#   'pieces': 339,
#   'pain': 339,
#   'kitchen': 334,
#   'pickles': 332,
#   'pancakes': 330,
#   'treat': 329,
#   'hummus': 326,
#   'wings': 319,
#   'buffet': 318,
#   'stew': 316,
#   'convenience': 316,
#   'bacon': 314,
#   'girl': 302,
#   'problems': 302,
#   'goods': 300,
#   'notch': 299,
#   'specials': 294,
#   'clams': 293,
#   'calamari': 292,
#   'tasting': 291,
#   'thai': 291,
#   'entrees': 289,
#   'desert': 288,
#   'glass': 288,
#   'dough': 285,
#   'ice cream': 285,
#   'cold': 283,
#   'crispy': 281,
#   'guacamole': 279,
#   'pizzas': 278,
#   'garlic': 269,
#   'bakery': 265,
#   'pie': 264,
#   'slice': 263,
#   'mussels': 262,
#   'find': 262,
#   'spice': 259,
#   'folks': 258,
#   'allergy': 256,
#   'naan': 255,
#   'family': 253,
#   'burrito': 253,
#   'combinations': 253,
#   'miracle': 251,
#   'noodle': 251,
#   'combo': 250,
#   'octopus': 248,
#   'bathroom': 246,
#   'beauty': 243,
#   'crap': 242,
#   'greens': 240,
#   'waffles': 240,
#   'juice': 238,
#   'mac': 238,
#   'passion': 237,
#   'duck': 236,
#   '  food': 235,
#   'selections': 235,
#   'cakes': 235,
#   'bars': 234,
#   'killer': 233,
#   'kick': 232,
#   'pita': 226,
#   'chairs': 224,
#   'trash': 224,
#   'allergies': 223,
#   'kids': 221,
#   'inside': 221,
#   'tomatoes': 220,
#   'punch': 217,
#   'bbq': 217,
#   'filling': 215,
#   'scallops': 214,
#   'shake': 214,
#   'eggplant': 212,
#   'bartender': 211,
#   'waste': 211,
#   'meats': 210,
#   'ribs': 209,
#   'cookies': 209,
#   'crab': 207,
#   'taco': 204,
#   'falafel': 203,
#   'entree': 202,
#   'cup': 201,
#   'alternative': 200,
#   'mushrooms': 200,
#   'pastry': 196,
#   'dressing': 196,
#   'store': 195,
#   'plantains': 193,
#   'fan': 193,
#   'spices': 191,
#   'rooms': 191,
#   'dog': 190,
#   'milk': 189,
#   'salt': 189,
#   'bagel': 188,
#   'hell': 187,
#   'bites': 186,
#   'go': 185,
#   'chocolates': 183,
#   'sangria': 183,
#   'latte': 182,
#   'yogurt': 179,
#   'vegan': 179,
#   'wines': 178,
#   'waffle': 178,
#   'peppers': 178,
#   'avocado': 173,
#   'onions': 172,
#   'stomach': 171,
#   'tuna': 171,
#   'boar': 171,
#   'corn': 171,
#   'summer': 169,
#   'boyfriend': 169,
#   'pad thai': 168,
#   'butter': 167,
#   'skin': 167,
#   'hands': 166,
#   'soups': 165,
#   'pepper': 164,
#   'pork belly': 164,
#   'sausage': 163,
#   'bottle': 163,
#   'pho': 162,
#   'neighborhood': 162,
#   'eater': 160,
#   'delicious': 160,
#   'care': 160,
#   'eats': 159,
#   'chunks': 159,
#   'assortment': 158,
#   'nights': 158,
#   'winner': 158,
#   'attention': 158,
#   'margarita': 157,
#   'some': 156,
#   'onion rings': 155,
#   'wrap': 155,
#   'waiter': 154,
#   'disaster': 153,
#   'mexican': 152,
#   'treats': 151,
#   'pudding': 151,
#   'pork fat': 151,
#   'pros': 150,
#   'pigs': 149,
#   'plenty': 149,
#   'craving': 148,
#   'spinach': 148,
#   'tooth': 148,
#   'stars': 147,
#   'bartenders': 147,
#   'standout': 147,
#   'knife': 147,
#   'crack': 144,
#   'ice': 144,
#   'food allergies': 143,
#   'chili': 143,
#   'garbage': 142,
#   'bowls': 140,
#   'cookie': 140,
#   'rings': 139,
#   'parts': 138,
#   'breads': 137,
#   'basil': 137,
#   'patrons': 136,
#   'flour': 136,
#   'bed': 136,
#   'shops': 135,
#   'mozzarella': 135,
#   'squash': 135,
#   'juices': 134,
#   'waitress': 132,
#   'heaven': 132,
#   'veggie': 132,
#   'belly': 131,
#   'vegetarian': 130,
#   'mouth': 130,
#   'home': 130,
#   'heat': 130,
#   'rabbit': 130,
#   'heart': 129,
#   'cauliflower': 128,
#   'sucker': 127,
#   'wood': 126,
#   'broccoli': 126,
#   'tasty': 125,
#   'lettuce': 125,
#   'cheesecake': 125,
#   'situation': 124,
#   'chefs': 124,
#   'chowder': 123,
#   'boba': 122,
#   'sashimi': 121,
#   'shame': 120,
#   'fav': 119,
#   'ravioli': 119,
#   'menus': 119,
#   'mom': 118,
#   'sort': 118,
#   'yucca': 117,
#   'miso': 117,
#   'chain': 117,
#   'mushroom': 116,
#   'smoothies': 116,
#   'nachos': 115,
#   'scratch': 115,
#   'tomato': 114,
#   'other': 114,
#   'brisket': 114,
#   'lemonade': 114,
#   'pumpkin': 112,
#   'balls': 112,
#   'fault': 111,
#   'takeout': 111,
#   'abundance': 111,
#   'compliment': 111,
#   'process': 111,
#   'gripe': 111,
#   'tips': 111,
#   'deli': 110,
#   'jerk': 110,
#   'dinners': 108,
#   'snack': 108,
#   'happiness': 107,
#   'product': 107,
#   'ways': 106,
#   'cocoa': 106,
#   'veggie burger': 106,
#   'helping': 106,
#   'sake': 106,
#   'cornbread': 106,
#   'sugar': 106,
#   'chai': 105,
#   'yourself': 105,
#   'boy': 104,
#   'chinese': 104,
#   'guests': 104,
#   'winter': 103,
#   'platter': 103,
#   'clam': 103,
#   'sprouts': 102,
#   'lover': 100,
#   'cravings': 100,
#   'cons': 99,
#   'ginger': 99,
#   'onion': 98,
#   'box': 98,
#   'need': 98,
#   'cooking': 98,
#   'cider': 98,
#   'peach': 97,
#   'diners': 97,
#   'tortilla': 97,
#   'batter': 95,
#   'tart': 95,
#   'joy': 94,
#   'gnocchi': 94,
#   'garden': 93,
#   'amounts': 93,
#   'apps': 92,
#   'fear': 92,
#   'medium': 92,
#   'types': 92,
#   'home fries': 92,
#   'pastrami': 91,
#   'fudge': 91,
#   'omelette': 91,
#   'themselves': 91,
#   'food quality': 90,
#   'tortillas': 90,
#   'honey': 89,
#   'hand': 89,
#   'burritos': 89,
#   'sub': 89,
#   'appetite': 89,
#   'rib': 88,
#   'duck fat': 87,
#   'shit': 87,
#   'grits': 87,
#   'hot': 86,
#   'espresso': 86,
#   'cod': 86,
#   'fave': 85,
#   'snacks': 85,
#   'tempura': 85,
#   'mixture': 85,
#   'soda': 84,
#   'overdone': 84,
#   'breakfast sandwich': 84,
#   'ingredient': 84,
#   'fajitas': 84,
#   'establishments': 84,
#   'clam chowder': 84,
#   'berries': 83,
#   'produce': 83,
#   'squid': 82,
#   'quesadilla': 82,
#   'wedge': 81,
#   'carrots': 81,
#   'risotto': 81,
#   'beverage': 80,
#   'beverages': 80,
#   'shack': 80,
#   'stress': 80,
#   'refills': 79,
#   'peas': 79,
#   'bean': 79,
#   'difficulty': 79,
#   'martini': 78,
#   'miss': 78,
#   'blossom': 78,
#   'hamburger': 78,
#   'patty': 78,
#   'preparation': 78,
#   'parents': 77,
#   'girls': 77,
#   'trick': 77,
#   'cups': 77,
#   'beets': 77,
#   'paneer': 77,
#   'syrup': 76,
#   'olives': 76,
#   'bread pudding': 76,
#   'dining room': 76,
#   'pour': 75,
#   'samples': 75,
#   'spread': 75,
#   'omelet': 75,
#   'joke': 75,
#   'alcohol': 74,
#   'bag': 74,
#   'smoothie': 74,
#   'combos': 74,
#   'lattes': 74,
#   'bottles': 74,
#   'mango': 74,
#   'meatballs': 74,
#   'leftovers': 73,
#   'biscuits': 73,
#   'subs': 73,
#   'wraps': 73,
#   'cabbage': 73,
#   'turkey': 73,
#   'feta': 72,
#   'bits': 72,
#   'fashion': 72,
#   'hint': 72,
#   'soul': 71,
#   'collection': 71,
#   'curries': 71,
#   'samosas': 71,
#   'gyoza': 71,
#   'drink menu': 70,
#   'baklava': 70,
#   'miso soup': 70,
#   'green': 70,
#   'cook': 70,
#   'soup dumplings': 70,
#   'char': 70,
#   'fritters': 70,
#   'flavorless': 70,
#   'app': 70,
#   'shakes': 69,
#   'counter': 69,
#   'pancake': 68,
#   'tongue': 68,
#   'eaters': 68,
#   'herbs': 67,
#   'blah': 67,
#   'melt': 67,
#   'harvest': 67,
#   'maki': 67,
#   'teas': 67,
#   'ourselves': 67,
#   'products': 66,
#   'win': 66,
#   'pastas': 66,
#   'chicken sandwich': 66,
#   'wifi': 66,
#   'lobster sandwich': 66,
#   'ricotta': 66,
#   'aioli': 65,
#   'muffin': 65,
#   'kale': 64,
#   'roast': 64,
#   'genius': 64,
#   'brussels': 64,
#   'beds': 64,
#   'lunch buffet': 64,
#   'everyone': 64,
#   'cappuccino': 64,
#   'junk': 63,
#   'strawberries': 63,
#   'superb': 63,
#   'layer': 63,
#   'dirt': 63,
#   'moist': 63,
#   'relief': 62,
#   'angel': 62,
#   'stall': 62,
#   '  drinks': 62,
#   'fish tacos': 62,
#   'flatbread': 62,
#   'self': 62,
#   'pool': 61,
#   'steal': 61,
#   'enchiladas': 61,
#   'croissants': 61,
#   'tapas': 61,
#   'cream cheese': 61,
#   'fresh': 61,
#   'spring rolls': 60,
#   'farm': 60,
#   'sour': 60,
#   'reuben': 60,
#   'women': 60,
#   'starter': 60,
#   'caesar': 60,
#   'steak tips': 59,
#   'wine selection': 59,
#   'mystery': 59,
#   'like': 59,
#   'gem': 59,
#   'kale salad': 59,
#   'calories': 58,
#   'beef stew': 58,
#   'catfish': 58,
#   'banana': 58,
#   'relish': 58,
#   'favorites': 58,
#   'blt': 58,
#   'eating': 57,
#   'ordering': 57,
#   'croissant': 57,
#   'chicken wings': 57,
#   'clover': 57,
#   'depth': 57,
#   'smile': 57,
#   'treatment': 57,
#   'jumbo': 56,
#   'ham': 56,
#   'dogs': 56,
#   'enough': 56,
#   'scallion pancakes': 56,
#   'benedict': 56,
#   'gyro': 55,
#   'tons': 55,
#   'baby': 55,
#   'vegetable': 55,
#   'cheeses': 55,
#   'mayo': 55,
#   'stalls': 55,
#   'vegetarians': 55,
#   'hash': 55,
#   'batch': 54,
#   'mustard': 54,
#   'magic': 54,
#   'pairing': 54,
#   'contamination': 54,
#   'mint': 53,
#   'fusion': 53,
#   'sweets': 53,
#   'seafood stew': 53,
#   'cilantro': 53,
#   'cow': 53,
#   'scallion': 52,
#   'fruits': 52,
#   'brioche': 52,
#   'breakdown': 52,
#   'dark': 52,
#   'fresher': 52,
#   'chill': 52,
#   'servings': 52,
#   'gravy': 52,
#   'shortage': 52,
#   'glasses': 52,
#   'cheeks': 51,
#   'meringue': 51,
#   'mango lassi': 51,
#   'cannoli': 51,
#   'twists': 50,
#   'tartare': 50,
#   'regret': 50,
#   'pies': 50,
#   'pinch': 50,
#   'tails': 50,
#   'fry': 50,
#   'patties': 50,
#   'sodas': 50,
#   'crab cakes': 49,
#   'fig jam': 49,
#   'bunch': 49,
#   'pickle': 49,
#   'knots': 49,
#   'omg': 49,
#   'ketchup': 49,
#   'bakeries': 48,
#   'eat': 48,
#   'scones': 48,
#   'book': 48,
#   'beet salad': 48,
#   'dust': 48,
#   'butternut': 48,
#   'lassi': 47,
#   'crisp': 47,
#   'varieties': 47,
#   'recipes': 47,
#   'lobby': 47,
#   'oyster': 47,
#   'areas': 47,
#   'shawarma': 47,
#   'swordfish': 47,
#   'burrata': 47,
#   'cause': 47,
#   'frappes': 47,
#   'bubble tea': 46,
#   'staple': 46,
#   'flakey': 46,
#   'vinaigrette': 46,
#   'cheddar': 46,
#   'cooks': 46,
#   'diet': 46,
#   'homemade': 46,
#   'confusion': 46,
#   'chew': 46,
#   'lunch menu': 46,
#   'muffins': 46,
#   'menu items': 45,
#   'cucumber': 45,
#   'chutney': 45,
#   'kimchi': 45,
#   'breading': 45,
#   'masala': 45,
#   'liquor': 45,
#   'pita bread': 45,
#   'sweet': 45,
#   'frappe': 45,
#   'ceviche': 45,
#   'pesto': 45,
#   'recipe': 44,
#   'gyros': 44,
#   'vanilla': 44,
#   'milk tea': 44,
#   'deserts': 44,
#   'boys': 44,
#   'bass': 44,
#   'spring': 44,
#   'dose': 44,
#   'myself': 44,
#   'puree': 44,
#   'pub': 43,
#   'sin': 43,
#   'waitstaff': 43,
#   'strawberry': 43,
#   'bon pain': 43,
#   'weight': 43,
#   'mash': 43,
#   'furniture': 43,
#   'majority': 43,
#   'lime': 42,
#   'meat lover': 42,
#   'leaves': 42,
#   'collard greens': 42,
#   'empanadas': 42,
#   'miso ramen': 42,
#   'bisque': 42,
#   'socks': 42,
#   'child': 42,
#   'cafe sushi': 42,
#   'pile': 42,
#   'clothes': 42,
#   'truck': 42,
#   'flowers': 42,
#   'pride': 42,
#   'bags': 42,
#   'asparagus': 42,
#   'arugula': 41,
#   'elements': 41,
#   'body': 41,
#   'skewers': 41,
#   'pistachio': 41,
#   'lacking': 41,
#   'brownie': 41,
#   'yolk': 41,
#   'bolognese': 41,
#   'bao': 41,
#   'cocktail menu': 41,
#   'zucchini': 41,
#   'vinegar': 41,
#   'quiche': 41,
#   'insult': 41,
#   'fish stew': 41,
#   'fool': 41,
#   'polenta': 40,
#   'crowd': 40,
#   'daughter': 40,
#   'custard': 40,
#   'egg sandwich': 40,
#   'fillings': 40,
#   'rare': 40,
#   'biscuit': 40,
#   'soo': 40,
#   'deliciousness': 40,
#   'soy': 40,
#   'hunger': 40,
#   'pots': 39,
#   'glaze': 39,
#   'pineapple': 39,
#   'dump': 39,
#   'tail': 39,
#   'pepperoni': 39,
#   'cheeseburger': 39,
#   'pairings': 39,
#   'boxes': 39,
#   'brunch menu': 39,
#   'bang': 39,
#   'nuts': 39,
#   'lunches': 39,
#   'nature': 39,
#   'ideas': 39,
#   'craigie': 38,
#   'accompaniments': 38,
#   'quail': 38,
#   'flan': 38,
#   'bulgogi': 38,
#   'goddess': 38,
#   'yay': 38,
#   'omelettes': 38,
#   'sesame': 38,
#   'breast': 38,
#   'bug': 38,
#   'pappardelle': 38,
#   'food allergy': 38,
#   'momos': 38,
#   'bananas': 38,
#   'o': 38,
#   'meatball': 38,
#   'grill': 38,
#   'broths': 38,
#   'omelets': 38,
#   'lobsters': 38,
#   'pad': 38,
#   'girlfriend': 38,
#   'super': 37,
#   'quesadillas': 37,
#   'buds': 37,
#   'beer menu': 37,
#   'bf': 37,
#   'cure': 37,
#   'alternatives': 37,
#   'sirloin': 37,
#   'doughy': 37,
#   'lunch specials': 37,
#   'gift': 37,
#   'gifts': 37,
#   'poutine': 37,
#   'spaghetti': 37,
#   'tomato sauce': 37,
#   'sticks': 37,
#   'help': 37,
#   'scallop': 37,
#   'sooooo': 37,
#   'meh': 37,
#   'dance': 37,
#   'lady': 36,
#   'complex': 36,
#   'pork chop': 36,
#   'staples': 36,
#   'awesomeness': 36,
#   'dipping sauce': 36,
#   'hamburgers': 36,
#   'lox': 36,
#   'waiters': 36,
#   'raspberry': 36,
#   'joints': 36,
#   'side dishes': 36,
#   'beef hash': 36,
#   'prosciutto': 36,
#   'pasta dishes': 36,
#   'chocolate cake': 36,
#   'starters': 36,
#   'son': 36,
#   'brussel sprouts': 35,
#   'curd': 35,
#   'complain': 35,
#   'gourmet': 35,
#   'paper': 35,
#   'breakfast sandwiches': 35,
#   '  coffee': 35,
#   'kinds': 35,
#   'carnitas': 35,
#   'mistakes': 35,
#   'rice pudding': 35,
#   'components': 35,
#   'nan': 34,
#   'fingers': 34,
#   'treasure': 34,
#   'prepared': 34,
#   'country': 34,
#   'parm': 34,
#   'needs': 34,
#   'chorizo': 34,
#   'pond': 34,
#   'chains': 34,
#   'food menu': 34,
#   'feat': 34,
#   'drink selection': 34,
#   'factory': 34,
#   'groups': 34,
#   'coffees': 34,
#   'takoyaki': 34,
#   'brussels sprouts': 34,
#   'biryani': 34,
#   'heads': 34,
#   'kid': 33,
#   'stores': 33,
#   'bruschetta': 33,
#   'cloud': 33,
#   'panini': 33,
#   'mac cheese': 33,
#   'snapper': 33,
#   'liver': 33,
#   'memories': 33,
#   'preparations': 33,
#   'tang': 33,
#   'yum': 33,
#   'steaks': 33,
#   'milkshakes': 33,
#   'bone': 33,
#   'lentil soup': 33,
#   'winners': 33,
#   'flavoring': 33,
#   'gluten': 33,
#   'samosa': 33,
#   'coconut': 33,
#   'packaging': 33,
#   'greek salad': 33,
#   'greek': 33,
#   'pitcher': 33,
#   'hotels': 33,
#   'apples': 32,
#   'sliders': 32,
#   'shock': 32,
#   'god': 32,
#   'marinade': 32,
#   'saag paneer': 32,
#   'hole': 32,
#   'peanuts': 32,
#   'haddock': 32,
#   'tikka masala': 32,
#   'meatloaf': 32,
#   'sit': 32,
#   'plants': 32,
#   'mousse': 32,
#   'handful': 32,
#   'bones': 32,
#   'corn bread': 32,
#   'barbecue': 32,
#   'pate': 31,
#   'beer garden': 31,
#   'macaroons': 31,
#   'beer punch': 31,
#   'tad': 31,
#   'damage': 31,
#   'substitute': 31,
#   'goat cheese': 31,
#   'baristas': 31,
#   'seaweed': 31,
#   'citrus': 31,
#   'dill': 31,
#   'donut': 31,
#   'chicken curry': 31,
#   'burn': 31,
#   'rich': 31,
#   'skill': 31,
#   'niku': 31,
#   'proportions': 31,
#   'crab rangoon': 31,
#   'bone marrow': 31,
#   'cover': 30,
#   'tourists': 30,
#   'hair': 30,
#   'revelation': 30,
#   'bliss': 30,
#   'roast beef': 30,
#   'tater': 30,
#   'culture': 30,
#   'whatever': 30,
#   'grass': 30,
#   'mice': 30,
#   'frites': 30,
#   'korma': 30,
#   'don': 30,
#   'strips': 30,
#   'guilt': 30,
#   'flounder': 30,
#   'chop': 30,
#   'fondue': 30,
#   'locals': 30,
#   'marrow': 29,
#   'heck': 29,
#   'tap': 29,
#   'raisins': 29,
#   'wontons': 29,
#   'addicting': 29,
#   'container': 29,
#   'wedges': 29,
#   'ipa': 29,
#   'tikka': 29,
#   'quantities': 29,
#   'tonight': 29,
#   'chops': 29,
#   'torta': 29,
#   'smear': 29,
#   'queso': 29,
#   'creme': 29,
#   'parties': 29,
#   'shelf': 29,
#   'monster': 28,
#   'lie': 28,
#   'habit': 28,
#   'meaty': 28,
#   'boiling': 28,
#   'donuts': 28,
#   'mole': 28,
#   'wheat': 28,
#   'lentils': 28,
#   'rangoon': 28,
#   'classics': 28,
#   'cubes': 28,
#   'scone': 28,
#   'bucks': 28,
#   'baguette': 28,
#   'latkes': 28,
#   'bit greasy': 28,
#   'scoop': 28,
#   'calzones': 28,
#   'children': 28,
#   'grease': 28,
#   'damn': 28,
#   'macaroni': 28,
#   'garlic naan': 28,
#   'gems': 27,
#   'blueberries': 27,
#   'truffle': 27,
#   'crudo': 27,
#   'mex': 27,
#   'moussaka': 27,
#   'legs': 27,
#   'few': 27,
#   'lobster bisque': 27,
#   'cinnamon': 27,
#   'candy': 27,
#   'tequila': 27,
#   'leaf': 27,
#   'trout': 27,
#   'sensation': 27,
#   'kofta': 27,
#   'mackerel': 27,
#   'cucumbers': 27,
#   ...},
#  'price': {'it': 8215,
#   'prices': 3804,
#   'spot': 3270,
#   'thing': 2986,
#   'price': 2554,
#   'me': 2455,
#   'amount': 2338,
#   'you': 2263,
#   'options': 2021,
#   'bar': 1877,
#   'nothing': 1468,
#   'that': 1234,
#   'choice': 1182,
#   'option': 1149,
#   'issue': 1109,
#   'deal': 1089,
#   'chips': 1071,
#   'bit': 1004,
#   'value': 935,
#   'size': 881,
#   'lot': 881,
#   'beers': 764,
#   'mistake': 751,
#   'touch': 750,
#   'disappointment': 721,
#   'combination': 685,
#   'what': 663,
#   'recommendation': 659,
#   'idea': 647,
#   'downside': 618,
#   'guy': 587,
#   'anything': 557,
#   'balance': 555,
#   'us': 550,
#   'this': 506,
#   'date': 492,
#   'luck': 486,
#   'good': 485,
#   'favor': 474,
#   'view': 466,
#   'bonus': 463,
#   'roll': 461,
#   'issues': 457,
#   'fact': 444,
#   'guys': 426,
#   'attitude': 425,
#   'owner': 419,
#   'concept': 405,
#   'fall': 399,
#   'reason': 391,
#   'surprise': 390,
#   'money': 381,
#   'setting': 356,
#   'excuse': 352,
#   'item': 344,
#   'right': 342,
#   'delivery': 339,
#   'than': 328,
#   'seats': 327,
#   'piece': 325,
#   'twist': 324,
#   'sides': 320,
#   'doubt': 292,
#   'look': 281,
#   'expectations': 274,
#   'level': 256,
#   'crunch': 255,
#   'fare': 254,
#   'advantage': 252,
#   'sum': 252,
#   'square': 251,
#   'break': 238,
#   'improvement': 236,
#   'tip': 218,
#   'type': 217,
#   'bill': 217,
#   'worth': 216,
#   'bet': 215,
#   'refund': 213,
#   'owners': 212,
#   'change': 206,
#   'end': 205,
#   'light': 202,
#   'try': 202,
#   'oil': 201,
#   'show': 194,
#   'decision': 188,
#   'point': 188,
#   'note': 182,
#   'pricing': 181,
#   'week': 181,
#   'rating': 177,
#   'street': 175,
#   'mind': 170,
#   'success': 170,
#   'gold': 168,
#   'range': 168,
#   'bargain': 159,
#   'cash': 159,
#   'risk': 157,
#   'suggestions': 154,
#   'floor': 153,
#   'benefit': 153,
#   'half': 151,
#   'orders': 151,
#   'cut': 148,
#   'concern': 148,
#   'portion size': 147,
#   'temperature': 143,
#   'classic': 142,
#   'bank': 140,
#   'corner': 139,
#   'wonder': 136,
#   'views': 135,
#   'dip': 134,
#   'looking': 132,
#   'contrast': 130,
#   'tops': 129,
#   'set': 128,
#   'chance': 128,
#   'cost': 123,
#   'ratio': 122,
#   'points': 121,
#   'portion sizes': 117,
#   'face': 116,
#   'months': 115,
#   'much': 113,
#   'shell': 112,
#   'thanks': 112,
#   'criticism': 112,
#   'appeal': 111,
#   'energy': 109,
#   '  prices': 108,
#   'quantity': 108,
#   'year': 107,
#   'little': 104,
#   'fortune': 104,
#   'deals': 103,
#   'penny': 103,
#   'factor': 103,
#   'pace': 103,
#   'kitchen sink': 101,
#   'wrong': 100,
#   'market': 100,
#   'delay': 98,
#   'more': 98,
#   'error': 97,
#   'basket': 95,
#   'comments': 93,
#   'ease': 91,
#   'sizes': 91,
#   'promise': 90,
#   'loss': 90,
#   'cuts': 89,
#   'someone': 89,
#   'tone': 88,
#   'lunch break': 88,
#   'mark': 88,
#   'timing': 87,
#   'pick': 86,
#   'looks': 85,
#   'moment': 84,
#   'words': 83,
#   'any': 81,
#   'share': 79,
#   'spite': 79,
#   'enthusiasm': 77,
#   'starbucks': 77,
#   'color': 77,
#   'behavior': 77,
#   'fail': 76,
#   'dollars': 75,
#   'shot': 74,
#   'move': 74,
#   'minute': 74,
#   'eye': 72,
#   'misses': 71,
#   'sink': 71,
#   'brown': 71,
#   'confidence': 71,
#   'ton': 69,
#   'luxury': 68,
#   'finish': 68,
#   'hang': 66,
#   'attempt': 66,
#   'reasons': 66,
#   'regard': 65,
#   'concerns': 65,
#   'of': 64,
#   'ending': 63,
#   'notes': 62,
#   'apple': 62,
#   'hit': 62,
#   'wifi': 61,
#   'case': 60,
#   'christopher': 60,
#   'standard': 58,
#   'likes': 58,
#   'yesterday': 58,
#   'bad': 57,
#   'shows': 57,
#   'plus': 56,
#   'noise level': 56,
#   'fix': 55,
#   'ball': 55,
#   'worries': 55,
#   'topping': 55,
#   'total': 53,
#   'b': 53,
#   'round': 53,
#   'signs': 52,
#   'c': 51,
#   'failure': 51,
#   'picture': 51,
#   'direction': 51,
#   'lobster roll': 51,
#   'reaction': 51,
#   'mr': 50,
#   'volume': 49,
#   'element': 49,
#   't': 48,
#   'suggestion': 48,
#   'limit': 48,
#   '100': 48,
#   'difference': 48,
#   'rate': 48,
#   "'s": 48,
#   'dates': 47,
#   'kong': 47,
#   'shape': 46,
#   'negative': 44,
#   'wall': 44,
#   'ends': 44,
#   'approach': 43,
#   'answer': 43,
#   'spin': 43,
#   'fit': 42,
#   's': 42,
#   'budget': 41,
#   'thought': 41,
#   'steal': 40,
#   'cheap': 40,
#   'question': 40,
#   'chip': 40,
#   'potential': 39,
#   'faces': 39,
#   'second': 39,
#   'trade': 39,
#   'turn': 39,
#   'fine': 38,
#   'ratings': 38,
#   'lead': 37,
#   'model': 37,
#   'match': 37,
#   'rise': 37,
#   'season': 37,
#   'month': 36,
#   'step': 36,
#   'decline': 36,
#   'moody': 36,
#   'dollar': 36,
#   'beyond': 36,
#   'bias': 35,
#   'absence': 35,
#   'drag': 35,
#   'perfect': 34,
#   'slack': 34,
#   'nice': 34,
#   'changes': 33,
#   'bread basket': 33,
#   'benefits': 33,
#   'offer': 33,
#   'flow': 33,
#   'best': 33,
#   'window': 33,
#   'parking lot': 32,
#   'result': 32,
#   'back': 32,
#   'limits': 32,
#   'rule': 32,
#   'boom': 32,
#   'bucks': 32,
#   'talk': 32,
#   'guess': 31,
#   'dips': 31,
#   'drop': 31,
#   'period': 31,
#   'pressure': 31,
#   'desire': 31,
#   'foot': 31,
#   'results': 30,
#   'explanation': 30,
#   'score': 30,
#   'hopes': 30,
#   'quarters': 30,
#   'split': 30,
#   'brand': 29,
#   'pair': 29,
#   'sun': 29,
#   'service issues': 29,
#   'price point': 29,
#   'i': 29,
#   'japanese': 28,
#   'prompt': 28,
#   'expensive': 27,
#   'flexibility': 27,
#   'interest': 27,
#   'attempts': 27,
#   'weakness': 27,
#   'turnover': 27,
#   'doubts': 27,
#   'star rating': 27,
#   'reward': 27,
#   'breaks': 26,
#   'rumors': 26,
#   'measure': 26,
#   'proportion': 26,
#   'term': 26,
#   'ceiling': 26,
#   'bottom': 26,
#   'marks': 26,
#   'pounds': 26,
#   'means': 26,
#   'component': 25,
#   'variation': 25,
#   'discount': 25,
#   'considering': 25,
#   'though': 25,
#   'decisions': 25,
#   'feet': 24,
#   'managers': 24,
#   '20': 24,
#   'showing': 24,
#   'relative': 24,
#   'fee': 24,
#   'average': 24,
#   'tortilla chips': 23,
#   'judgment': 23,
#   'troubles': 23,
#   'promises': 23,
#   'grafton street': 23,
#   'price tag': 23,
#   'expectation': 23,
#   'burden': 23,
#   'variations': 22,
#   'hits': 22,
#   'method': 22,
#   'drive': 22,
#   'threat': 22,
#   'temple bar': 22,
#   'wind': 22,
#   'ticket': 22,
#   'draft': 22,
#   'catalyst': 22,
#   'worry': 21,
#   'car': 21,
#   'going': 21,
#   'suit': 21,
#   'stick': 21,
#   'power': 21,
#   'savings': 21,
#   'mcdonald': 21,
#   'slow': 21,
#   'count': 21,
#   'stand': 21,
#   'resistance': 21,
#   'thinking': 21,
#   'strategy': 21,
#   'delivery guy': 21,
#   'bubble': 20,
#   'slap': 20,
#   'steel': 20,
#   'metal': 20,
#   'weeks': 20,
#   'arrangement': 20,
#   'values': 20,
#   'terms': 20,
#   'my': 20,
#   'blame': 20,
#   'h': 19,
#   'fears': 19,
#   'cents': 19,
#   'shanghai': 19,
#   'meaning': 19,
#   'shots': 19,
#   'overall': 19,
#   'key': 19,
#   'levels': 18,
#   'buyer': 18,
#   'pickup': 18,
#   'edge': 18,
#   'performance': 18,
#   'stock': 18,
#   'indication': 17,
#   'dispute': 17,
#   'spice level': 17,
#   'menu options': 17,
#   'fi': 17,
#   'fair': 17,
#   'grab': 17,
#   'goal': 17,
#   'side note': 17,
#   'about': 17,
#   'effect': 17,
#   'cent': 17,
#   'challenge': 17,
#   'trend': 16,
#   'baker': 16,
#   'comparison': 16,
#   'policies': 16,
#   'time limit': 16,
#   'mike': 16,
#   'economy': 16,
#   'steps': 15,
#   'james': 15,
#   'food options': 15,
#   'core': 15,
#   '30': 15,
#   'catch': 15,
#   'tuna roll': 15,
#   'basis': 15,
#   'estate': 15,
#   'rates': 15,
#   '40': 15,
#   'tomorrow': 15,
#   'recession': 15,
#   'tom': 15,
#   'boost': 15,
#   'charges': 15,
#   'chances': 15,
#   'moves': 15,
#   'argument': 15,
#   'definition': 14,
#   'hike': 14,
#   'premium': 14,
#   'seeing': 14,
#   'spring break': 14,
#   'rose': 14,
#   'table tops': 14,
#   'sets': 14,
#   'activity': 14,
#   'estimate': 14,
#   'pound': 14,
#   'coupon': 13,
#   '  bonus': 13,
#   'picks': 13,
#   'bets': 13,
#   'beer prices': 13,
#   'session': 13,
#   'movie': 13,
#   'coke': 13,
#   'hard': 13,
#   'strength': 13,
#   'making': 13,
#   'exchange': 13,
#   '25': 13,
#   'temperatures': 13,
#   'salad bar': 13,
#   'height': 12,
#   'grade': 12,
#   'wine recommendation': 12,
#   'food prices': 12,
#   'restaurant week': 12,
#   'blue': 12,
#   'loser': 12,
#   'drink prices': 12,
#   'account': 12,
#   'rooftop bar': 12,
#   'formula': 12,
#   'barrel': 12,
#   'lunch breaks': 12,
#   'preference': 12,
#   'heck': 12,
#   'pocket': 12,
#   '3.5': 12,
#   'limitations': 12,
#   'chocolate chip': 12,
#   'minimum': 11,
#   'efficiency': 11,
#   'losers': 11,
#   'fraud': 11,
#   'tag': 11,
#   'if': 11,
#   'rent': 11,
#   'reality': 11,
#   'think': 11,
#   'demand': 11,
#   'buy': 11,
#   'credit': 11,
#   'tension': 11,
#   'appreciation': 11,
#   'influence': 11,
#   'lunch options': 11,
#   'turnaround': 11,
#   'potato chips': 11,
#   'purchase': 11,
#   'balanced': 11,
#   'rough': 11,
#   'popularity': 11,
#   'measures': 11,
#   'meter': 11,
#   'indicator': 11,
#   'japan': 10,
#   'off': 10,
#   'lunch prices': 10,
#   'frame': 10,
#   'iron': 10,
#   "'": 10,
#   'mart': 10,
#   'risks': 10,
#   'disadvantage': 10,
#   'jack': 10,
#   'breakfast options': 10,
#   'tickets': 10,
#   'losses': 10,
#   'kendall square': 10,
#   'banana split': 10,
#   'crunch roll': 10,
#   'room temperature': 10,
#   'tax': 10,
#   'cap': 10,
#   'priced': 10,
#   'flavor combination': 10,
#   'costs': 10,
#   'movies': 10,
#   'menu changes': 10,
#   'disappointing': 10,
#   'asset': 9,
#   'recovery': 9,
#   'assumption': 9,
#   'bills': 9,
#   'shift': 9,
#   'service issue': 9,
#   'refills': 9,
#   'sheet': 9,
#   'circumstances': 9,
#   'payment': 9,
#   'is': 9,
#   'dipping': 9,
#   'receipt': 9,
#   'satisfy': 9,
#   'numbers': 9,
#   'rival': 9,
#   'counters': 9,
#   'less': 9,
#   'rainbow roll': 9,
#   'see': 9,
#   'fish chips': 9,
#   'steve': 9,
#   'pre': 9,
#   'scale': 9,
#   '80': 9,
#   'angle': 9,
#   'nickel': 9,
#   'up': 8,
#   'summer fall': 8,
#   'line moves': 8,
#   'hold': 8,
#   'peak': 8,
#   'fight': 8,
#   'row': 8,
#   'differences': 8,
#   'cars': 8,
#   'veggie options': 8,
#   'sums': 8,
#   'solid': 8,
#   'demi size': 8,
#   '50': 8,
#   'past': 8,
#   'offs': 8,
#   'scrap': 8,
#   'sushi bar': 8,
#   'makers': 8,
#   'property': 8,
#   'food critics': 8,
#   'expense': 8,
#   'minus': 8,
#   'co.': 8,
#   'outcome': 8,
#   'g': 8,
#   'compromise': 8,
#   'dive bar': 8,
#   'juice bar': 8,
#   'menu item': 8,
#   'impact': 8,
#   'crab dip': 8,
#   'designs': 8,
#   'reduction': 8,
#   'film': 8,
#   'freeze': 7,
#   'rib eye': 7,
#   'makes': 7,
#   'factors': 7,
#   'porter square': 7,
#   'sandwich star bar': 7,
#   'topped': 7,
#   'drink options': 7,
#   'sentence': 7,
#   'chocolate bar': 7,
#   'theory': 7,
#   'consensus': 7,
#   'string': 7,
#   'dance floor': 7,
#   'george': 7,
#   'close': 7,
#   '  beers': 7,
#   'seating options': 7,
#   'high': 7,
#   'hour limit': 7,
#   'anticipation': 7,
#   'brunch options': 7,
#   'cinnamon roll': 7,
#   'happy': 7,
#   'rewards': 7,
#   'oreos': 7,
#   'coming': 7,
#   'meat options': 7,
#   'gain': 7,
#   'satisfaction': 7,
#   'down': 7,
#   'critics': 7,
#   'pull': 7,
#   'david': 7,
#   'salsa': 7,
#   'menu prices': 7,
#   'minute delay': 7,
#   'end result': 7,
#   'wage': 7,
#   'intention': 7,
#   'compensation': 7,
#   'manager owner': 7,
#   'maker': 7,
#   'crinkle cut': 7,
#   'judging': 6,
#   'slices': 6,
#   'sale': 6,
#   'scott': 6,
#   'seating arrangement': 6,
#   'apartment': 6,
#   'criteria': 6,
#   'banks': 6,
#   'chicken buffalo dip': 6,
#   'winter break': 6,
#   'buck': 6,
#   'revenue': 6,
#   'proof': 6,
#   'spring roll': 6,
#   'strong': 6,
#   'transaction': 6,
#   'markets': 6,
#   'study break': 6,
#   'dollars worth': 6,
#   'draft beers': 6,
#   'tad': 6,
#   'record': 6,
#   'anybody': 6,
#   'california roll': 6,
#   'sell': 6,
#   'draw': 6,
#   'pay': 6,
#   'mean': 6,
#   'ratios': 6,
#   'bonuses': 6,
#   'compare': 6,
#   'let': 6,
#   'dynamic': 6,
#   'claim': 6,
#   'firm': 6,
#   'increase': 6,
#   'spectrum': 6,
#   'spark': 6,
#   'bout': 6,
#   'length': 6,
#   'ripoff': 6,
#   'tempura roll': 6,
#   '  delivery': 6,
#   'art bar': 6,
#   'downgrade': 6,
#   'sentiment': 6,
#   'k': 6,
#   'ramen': 6,
#   'insight': 6,
#   'figure': 6,
#   'egg roll': 6,
#   'cost benefit': 5,
#   'advantages': 5,
#   'entrees': 5,
#   'wages': 5,
#   'portions sizes': 5,
#   'drops': 5,
#   'health benefits': 5,
#   'consistent': 5,
#   'profit': 5,
#   'counter guy': 5,
#   'big': 5,
#   'chow show': 5,
#   'quarter': 5,
#   'debt': 5,
#   'bargains': 5,
#   'cycle': 5,
#   'communication issues': 5,
#   'quote': 5,
#   'gripe': 5,
#   'space issues': 5,
#   'toppings': 5,
#   'holders': 5,
#   'thin': 5,
#   'consideration': 5,
#   'squeeze': 5,
#   'cigarette': 5,
#   'keeping': 5,
#   'consumers': 5,
#   'march': 5,
#   'vote': 5,
#   'bar tops': 5,
#   'price points': 5,
#   'low': 5,
#   'designer': 5,
#   'brisk': 5,
#   'guacamole': 5,
#   'lag': 5,
#   'water pressure': 5,
#   'greasy': 5,
#   'default': 5,
#   'third': 5,
#   'comparing': 5,
#   'gross': 5,
#   'ownership': 5,
#   'sticker': 5,
#   'downturn': 5,
#   'gas': 5,
#   'delivery guys': 5,
#   'penalty': 5,
#   'health concerns': 5,
#   'par': 5,
#   'gains': 5,
#   'beer options': 5,
#   'put': 5,
#   'burrito': 5,
#   'stomach issues': 5,
#   'waffles': 5,
#   'sample limit': 5,
#   'incentive': 5,
#   'pub fare': 5,
#   'tony': 5,
#   'davis': 5,
#   'queso dip': 5,
#   'food item': 5,
#   'porter exchange': 4,
#   'dessert options': 4,
#   'quality issues': 4,
#   'holder': 4,
#   'p': 4,
#   'percentage': 4,
#   'lunch deals': 4,
#   'mirror': 4,
#   'usual': 4,
#   'delivery fee': 4,
#   'pita chips': 4,
#   'rents': 4,
#   'belief': 4,
#   'tough': 4,
#   'ramen spot': 4,
#   'offset': 4,
#   'lunch hour break': 4,
#   'sandwich options': 4,
#   '  value': 4,
#   'wave': 4,
#   'aggressive': 4,
#   'cons': 4,
#   'fish market': 4,
#   'transactions': 4,
#   'tad bit': 4,
#   'downsides': 4,
#   'sellers': 4,
#   'surcharge': 4,
#   '  sides': 4,
#   'bean dip': 4,
#   'hash brown': 4,
#   'time mistake': 4,
#   'side orders': 4,
#   'coffee break': 4,
#   'bounce': 4,
#   'maturity': 4,
#   'claims': 4,
#   'study breaks': 4,
#   'summer roll': 4,
#   'bonus points': 4,
#   'yard sale': 4,
#   'wi': 4,
#   'diamond': 4,
#   'brain freeze': 4,
#   '  pricing': 4,
#   'diesel': 4,
#   'liability': 4,
#   'coffee bar': 4,
#   'hurt': 4,
#   'july': 4,
#   'f': 4,
#   'pizza bar': 4,
#   'slice': 4,
#   'extra': 4,
#   'temple   bar': 4,
#   'salt level': 4,
#   'seems': 4,
#   'music choice': 4,
#   'mechanism': 4,
#   'better': 4,
#   'exceptions': 4,
#   'cocktail options': 4,
#   'net': 4,
#   'worst': 4,
#   '  price': 4,
#   'scores': 4,
#   'vegan options': 4,
#   'seller': 4,
#   'sakana roll': 4,
#   'stake': 4,
#   'pattern': 4,
#   'service prompt': 4,
#   'gyoza': 4,
#   '  buyer': 4,
#   'noise levels': 4,
#   'h mart': 4,
#   'gallon': 4,
#   'opposite': 4,
#   'house beers': 4,
#   'audacity': 4,
#   'tacos': 4,
#   'we': 4,
#   'say': 4,
#   'chef owner': 4,
#   'brian': 4,
#   'load': 4,
#   'time limits': 4,
#   'gm': 4,
#   'perception': 4,
#   'greek corner': 4,
#   'principle': 4,
#   'reference': 4,
#   'russell': 4,
#   'yay': 3,
#   'hour prices': 3,
#   'reach': 3,
# ...
#   'decoration': 8,
#   'victim': 8,
#   'franchise': 8,
#   'vehicle': 8,
#   'damper': 8,
#   'customer experience': 7,
#   'dark': 7,
#   'device': 7,
#   'sigh': 7,
#   'laws': 7,
#   'church': 7,
#   'advocate': 7,
#   'fi': 7,
#   'save': 7,
#   'bell': 7,
#   'dissatisfaction': 7,
#   'priority': 7,
#   'under': 7,
#   'stares': 7,
#   'counter person': 7,
#   'restaurant space': 7,
#   'john': 7,
#   'platform': 7,
#   'ignorance': 7,
#   'olives': 7,
#   'yelp': 7,
#   'engagement': 7,
#   'protection': 7,
#   're': 7,
#   'article': 7,
#   'wednesday': 7,
#   'ten': 7,
#   'festival': 7,
#   'aloof': 7,
#   'letter': 7,
#   'hip': 7,
#   'sushi place': 7,
#   'university': 7,
#   'slot': 7,
#   'wallet': 7,
#   'walls': 7,
#   'patronage': 7,
#   'return visit': 7,
#   ...},
#  'misc': {'waitress': 53,
#   'ramen': 39,
#   'shake': 39,
#   'notch': 35,
#   'chill': 32,
#   'margaritas': 30,
#   'tacos': 25,
#   'stars': 24,
#   'wifi': 21,
#   'pros': 21,
#   'oysters': 19,
#   'dirt': 19,
#   'waiter': 17,
#   'entrees': 17,
#   'waitstaff': 17,
#   'cons': 17,
#   'pride': 17,
#   'desert': 17,
#   'nightmare': 16,
#   'bartenders': 15,
#   'shack': 15,
#   'greasy': 14,
#   'mediocre': 13,
#   'burrito': 12,
#   'waffles': 11,
#   'espresso': 11,
#   'toppings': 10,
#   'tag': 9,
#   'margarita': 9,
#   'combo': 9,
#   'plates': 9,
#   'smoothies': 9,
#   'hole': 9,
#   'waiters': 8,
#   'bucks': 8,
#   'wallet': 8,
#   'bang': 8,
#   'pizzas': 8,
#   'bowls': 7,
#   'bbq': 7,
#   'plate': 7,
#   'steal': 7,
#   'lobsters': 7,
#   'blah': 7,
#   'pricy': 7,
#   'tad': 7,
#   'bagels': 7,
#   'hell': 6,
#   'winner': 6,
#   'price tag': 6,
#   'clover': 6,
#   'pho': 6,
#   'buns': 6,
#   'salsa': 6,
#   'fi': 5,
#   'shame': 5,
#   'crowd': 5,
#   'guacamole': 5,
#   'pub': 5,
#   'refills': 5,
#   'crap': 5,
#   'tart': 5,
#   'appetizers': 5,
#   'pitchers': 5,
#   'shake shack': 5,
#   'cannoli': 5,
#   'joints': 5,
#   'inconvenience': 5,
#   'gripe': 4,
#   'monkey': 4,
#   'quibbles': 4,
#   'shock': 4,
#   'appetizer': 4,
#   'goodness': 4,
#   'lattes': 4,
#   'fault': 4,
#   'latte': 4,
#   'killer': 4,
#   'apps': 4,
#   'pairings': 4,
#   'hat': 4,
#   'pop': 4,
#   'win': 4,
#   'grub': 4,
#   'burritos': 4,
#   'joke': 4,
#   'hostesses': 3,
#   'pan': 3,
#   'steaks': 3,
#   'rip': 3,
#   'milk shake': 3,
#   'coffees': 3,
#   'deliciousness': 3,
#   'drawback': 3,
#   'nonsense': 3,
#   'passion': 3,
#   'scratch': 3,
#   'borderline': 3,
#   'myself': 3,
#   'sin': 3,
#   'fresher': 3,
#   'boba': 3,
#   'gyro': 3,
#   'splurge': 3,
#   'downsides': 3,
#   'dearth': 3,
#   'god': 3,
#   'jazz': 3,
#   'enchiladas': 3,
#   'cashiers': 3,
#   'swordfish': 3,
#   'veggies': 3,
#   'fuji': 3,
#   'selections': 3,
#   'darwin': 3,
#   'pies': 3,
#   'felipe': 3,
#   'pond': 3,
#   'knots': 3,
#   'ole': 3,
#   'nachos': 3,
#   'servings': 3,
#   'freakin': 3,
#   'hummus': 3,
#   'boring': 3,
#   'oreo': 3,
#   'wow': 3,
#   'mex': 3,
#   'booze': 3,
#   'scoop': 3,
#   'frustration': 3,
#   'highlight': 3,
#   'beat': 3,
#   'halibut': 3,
#   'wings': 3,
#   'groupon': 3,
#   'tikka': 3,
#   'gems': 2,
#   '8.50': 2,
#   'bug': 2,
#   'jerk': 2,
#   'booths': 2,
#   'sommelier': 2,
#   'ripoff': 2,
#   'favorites': 2,
#   'abortion': 2,
#   'eater': 2,
#   'cupcake': 2,
#   'tequila': 2,
#   'min': 2,
#   'robbery': 2,
#   'miss': 2,
#   'bartender': 2,
#   'baklava': 2,
#   'tags': 2,
#   'anxiety': 2,
#   'maki': 2,
#   'miso': 2,
#   'uber': 2,
#   'smile': 2,
#   'perks': 2,
#   'app': 2,
#   'bumps': 2,
#   'charcuterie': 2,
#   'patties': 2,
#   'sq': 2,
#   'punjabi dhaba': 2,
#   'curt': 2,
#   'downfall': 2,
#   'samosas': 2,
#   'udon': 2,
#   'slices': 2,
#   'yucca': 2,
#   'knowledgeable': 2,
#   'ness': 2,
#   'syrups': 2,
#   'waffle': 2,
#   'oreos': 2,
#   'drafts': 2,
#   'skewers': 2,
#   'cones': 2,
#   'brusque': 2,
#   'standout': 2,
#   'def': 2,
#   'yay': 2,
#   'wrap': 2,
#   'regatta': 2,
#   'silverware': 2,
#   'dave': 2,
#   'imo': 2,
#   'donut': 2,
#   'vanilla': 2,
#   'sangria': 2,
#   'walls': 2,
#   'chai': 2,
#   'bastard': 2,
#   'proportions': 2,
#   'joy': 2,
#   'flaw': 2,
#   'veggie': 2,
#   'cafe luna': 2,
#   'waitresses': 2,
#   'chipotle': 2,
#   'mimosa': 2,
#   'knock': 2,
#   'hotpot': 2,
#   'helpings': 2,
#   'ac': 2,
#   'characters': 2,
#   'muffin': 2,
#   'pastas': 2,
#   'starter': 2,
#   'morsels': 2,
#   'pours': 2,
#   'qualm': 2,
#   'everytime': 2,
#   'plating': 2,
#   'caf': 2,
#   'fajitas': 2,
#   'glasses': 2,
#   'blanc': 2,
#   'inviting': 2,
#   'bullshit': 2,
#   'chutneys': 2,
#   'scallops': 2,
#   'tonight': 2,
#   'food runners': 2,
#   'milkshakes': 2,
#   'victory': 2,
#   'shakes': 2,
#   'arepas': 2,
#   'patience': 2,
#   'scones': 2,
#   'omelettes': 2,
#   'chicken wings': 2,
#   'portrayal': 2,
#   'shirt': 2,
#   'greek': 2,
#   'tourist trap': 2,
#   'food mediocre': 2,
#   'snobby': 2,
#   'bouche': 2,
#   'bun': 2,
#   'poutine': 2,
#   'superb': 2,
#   'mains': 2,
#   'punjabi': 2,
#   'terri': 2,
#   'indecisive': 1,
#   'jasper': 1,
#   'macaroon': 1,
#   'needless': 1,
#   'lord': 1,
#   'upstairs': 1,
#   'pints': 1,
#   'buddy': 1,
#   'drinker': 1,
#   'super': 1,
#   'subset': 1,
#   'fist': 1,
#   'boo yah': 1,
#   'lobster tail': 1,
#   'shays': 1,
#   'v.': 1,
#   '  caitlin': 1,
#   'croissants': 1,
#   'jerk wings': 1,
#   'forgot': 1,
#   'libations': 1,
#   'fixe': 1,
#   'chunks': 1,
#   'negatives': 1,
#   'rows': 1,
#   'whites': 1,
#   'remoulade': 1,
#   'perspective': 1,
#   'pears': 1,
#   'stench': 1,
#   'overs': 1,
#   'bento': 1,
#   'mustache': 1,
#   'zucchini': 1,
#   'kimchi': 1,
#   'meaty': 1,
#   'mistakes': 1,
#   'daal': 1,
#   'biryani': 1,
#   'doting': 1,
#   'justification': 1,
#   'skillet': 1,
#   'melons': 1,
#   'aversion': 1,
#   'combo platters': 1,
#   'hideouts': 1,
#   'photos': 1,
#   'viale': 1,
#   'chocolate souffle': 1,
#   'fruit peach': 1,
#   'cor': 1,
#   'den': 1,
#   'fave': 1,
#   'drunk': 1,
#   'linguine': 1,
#   'weaknesses': 1,
#   'sucker': 1,
#   'pluses': 1,
#   'flops': 1,
#   'basil': 1,
#   'basil whore': 1,
#   'takemura': 1,
#   'tragedy': 1,
#   'teeny': 1,
#   'merry': 1,
#   'blossom': 1,
#   '  waitstaff': 1,
#   'buff': 1,
#   'ambassadors': 1,
#   '  terri': 1,
#   'scallion': 1,
#   'khao': 1,
#   'whiskey smash': 1,
#   'standouts': 1,
#   'interpretation': 1,
#   'broccoli': 1,
#   'tater tots': 1,
#   'west coasters': 1,
#   'ghetto': 1,
#   'surya': 1,
#   '10.95': 1,
#   'shabu': 1,
#   'brazilian': 1,
#   'shanghainese': 1,
#   'mango smoothie': 1,
#   'catfish fajitas': 1,
#   'lutes trademarks': 1,
#   'sacrifice': 1,
#   'glory': 1,
#   'swag': 1,
#   'berbere': 1,
#   'mi': 1,
#   'inconsistency': 1,
#   'penne': 1,
#   'mariposa': 1,
#   'marzipan': 1,
#   'executions': 1,
#   'nope': 1,
#   'obscurity': 1,
#   'souls': 1,
#   'authenticity': 1,
#   'wine glasses': 1,
#   'singing': 1,
#   'fruity smack': 1,
#   'rioja': 1,
#   'iron pan': 1,
#   'veggie ramen': 1,
#   'pepperoni': 1,
#   'hef': 1,
#   'baristas': 1,
#   'disgrace': 1,
#   'tutti': 1,
#   'scam': 1,
#   'competent': 1,
#   'chunk': 1,
#   'rooftop': 1,
#   'hur hur': 1,
#   '17th': 1,
#   'tater': 1,
#   'tee': 1,
#   'personalities': 1,
#   'mystery': 1,
#   'swallow': 1,
#   'scallion pancakes': 1,
#   'portions cons': 1,
#   'roof': 1,
#   'omakase': 1,
#   'couches': 1,
#   'decorations': 1,
#   'potency': 1,
#   'purple': 1,
#   'food pacing': 1,
#   'skipping': 1,
#   'hypocrite': 1,
#   'pricier': 1,
#   'lame': 1,
#   'sans': 1,
#   'music inconsistent': 1,
#   'rotation': 1,
#   'buffets': 1,
#   'ole mediocre': 1,
#   'cent oysters': 1,
#   'edamame': 1,
#   'jeez': 1,
#   'meh': 1,
#   'methinks': 1,
#   'shit': 1,
#   'flavorless': 1,
#   'd. a.': 1,
#   'knife': 1,
#   'falafel': 1,
#   'taste buds': 1,
#   'anna': 1,
#   'brisket': 1,
#   'zombie': 1,
#   'henrietta': 1,
#   'ppl': 1,
#   'beer lover': 1,
#   'au': 1,
#   'princes': 1,
#   'temps': 1,
#   'fav': 1,
#   'amt': 1,
#   'gf': 1,
#   'service wrinkles': 1,
#   'hemmingway': 1,
#   'hibachi': 1,
#   'size demi': 1,
#   'camper': 1,
#   'atmosphere cons': 1,
#   'service superb': 1,
#   'ribs': 1,
#   'comforter': 1,
#   'health hazard': 1,
#   'prestige': 1,
#   'willingness': 1,
#   'eggs   benedict': 1,
#   'downstairs': 1,
#   'daze': 1,
#   'flatbread': 1,
#   'oven': 1,
#   'pants': 1,
#   'americanos': 1,
#   'floors': 1,
#   'cbc': 1,
#   'stomach guilt': 1,
#   'trek': 1,
#   'menu appetizers': 1,
#   'gem': 1,
#   'mini': 1,
#   'concerts': 1,
#   'commandments': 1,
#   'abbey': 1,
#   'helmand': 1,
#   'mackerel': 1,
#   'service portillo': 1,
#   'tzatziki': 1,
#   'taipei': 1,
#   'brain': 1,
#   'artists': 1,
#   'inedible': 1,
#   'cortado': 1,
#   'undercroft': 1,
#   'grossness': 1,
#   'karmen': 1,
#   'toscano': 1,
#   'haha': 1,
#   'harrow': 1,
#   'meatball': 1,
#   'changer cream amaaaazing capers': 1,
#   'taqueria': 1,
#   'punctual': 1,
#   'crispy': 1,
#   'cheeseburger': 1,
#   '10x': 1,
#   'izakaya': 1,
#   'tale': 1,
#   'regret': 1,
#   'logic': 1,
#   'tapas': 1,
#   'bao': 1,
#   'buddha': 1,
#   'lies': 1,
#   'overpriced': 1,
#   'dinner entrees': 1,
#   'mishaps': 1,
#   'whack': 1,
#   'goody': 1,
#   'pita': 1,
#   'shoutout': 1,
#   'indonesian': 1,
#   'meat combo': 1,
#   'katsu': 1,
#   'horchata': 1,
#   'grapes': 1,
#   'trattoria': 1,
#   'marvel': 1,
#   'stranger': 1,
#   'yakitori piece combo': 1,
#   'chaat': 1,
#   'rater': 1,
#   '  enchiladas': 1,
#   'gin': 1,
#   'fuss': 1,
#   'ere': 1,
#   'esp': 1,
#   'candle': 1,
#   'rollers': 1,
#   'taters': 1,
#   'top notch': 1,
#   'wisdom': 1,
#   'ps': 1,
#   'recs': 1,
#   'flan': 1,
#   'caipirinha': 1,
#   'price tags': 1,
#   'bouch': 1,
#   'thumbs': 1,
#   'trophy': 1,
#   'galleria': 1,
#   'oyster': 1,
#   'boot': 1,
#   'pizza pan': 1,
#   'siracha wings': 1,
#   'satisfies': 1,
#   'masters': 1,
#   'belly': 1,
#   'carnivore': 1,
#   'woot': 1,
#   'oz': 1,
#   'hash': 1,
#   'driving nightmare': 1,
#   'caesar': 1,
#   'onion strings': 1,
#   'wanna': 1,
#   'brioche': 1,
#   'holes': 1,
#   'moist': 1,
#   'quesadilla appetizer': 1,
#   'mussels': 1,
#   'teas': 1,
#   'veggie wrap': 1,
#   'aways': 1,
#   'reign': 1,
#   'growlers': 1,
#   "s'mores shake": 1,
#   'pale': 1,
#   'river porter': 1,
#   'pennies': 1,
#   'accolades': 1,
#   'substitution': 1,
#   'tortillas': 1,
#   'paucity': 1,
#   'y.': 1,
#   'enlightenment': 1,
#   'queer': 1,
#   'capital grille': 1,
#   'mus': 1,
#   'faire': 1,
#   'entr': 1,
#   'hangover': 1,
#   'depression': 1,
#   'flourish': 1,
#   'addict': 1,
#   'shepard': 1,
#   'hostess': 1,
#   'naan': 1,
#   'microorganisms': 1,
#   '88': 1,
#   'hooray': 1,
#   'cuban': 1,
#   'jefe': 1,
#   'pitcher': 1,
#   'mcdonalds': 1,
#   'omelets': 1,
#   'meatloaf': 1,
#   'dough': 1,
#   'calamari': 1,
#   '4.95': 1,
#   'mole': 1,
#   'squash': 1,
#   'scorpion': 1,
#   'alcohol paradise': 1,
#   'genius': 1,
#   'standby': 1,
#   'beantown taqueria': 1,
#   'murder': 1,
#   'musicians': 1,
#   'superiority': 1,
#   'lady': 1,
#   'yummy': 1,
#   'granola': 1,
#   'chocolate mice': 1,
#   'rib': 1,
#   'compliment': 1,
#   'rellenos': 1,
#   'kudos': 1,
#   'brewery': 1,
#   'beats': 1,
#   'inconsistent': 1,
#   'horrible': 1,
#   'disregard': 1,
#   'sass': 1,
#   'asgard': 1,
#   'myth': 1,
#   'feedback': 1,
#   'crust': 1,
#   'pd': 1,
#   'coffee mediocre': 1,
#   'charisma': 1,
#   'yum': 1,
#   'heck': 1,
#   'cornbread': 1,
#   'nirvana': 1,
#   'decaf': 1,
#   'displeasure': 1,
#   'eel': 1,
#   'cake plastic knife': 1,
#   'sashimi': 1,
#   'tenders': 1,
#   'paradise': 1,
#   'takoyaki': 1,
#   'smoothie': 1,
#   'racist': 1,
#   'defect': 1,
#   'monk': 1,
#   'roll lover': 1,
#   'motel': 1,
#   'prick': 1,
#   'oyster bao': 1,
#   'sever': 1,
#   'feta': 1,
#   'biases': 1,
#   'ricotta': 1,
#   'barista': 1,
#   'rubbing': 1,
#   'gripes': 1,
#   'borderline rude': 1,
#   'stare': 1,
#   'combinations': 1,
#   'kabab': 1,
#   'spoon': 1,
#   'socks': 1,
#   'greens': 1,
#   'kiwis': 1,
#   'patisserie': 1,
#   'ear': 1,
#   'sammie': 1,
#   'bf cons': 1,
#   'tortilla': 1,
#   'peeve': 1,
#   'briney goodness': 1,
#   'buds': 1,
#   'idiot': 1,
#   'viruses': 1,
#   'kibby': 1,
#   'chao': 1,
#   'sun phobic': 1,
#   'dosa': 1,
#   'linens': 1,
#   'taps': 1,
#   'cherry tart': 1,
#   'drinking margaritas': 1,
#   'guilt': 1,
#   'pbr': 1,
#   'bugs': 1,
#   'aspirations': 1,
#   'dash': 1,
#   'fluctuates': 1,
#   'kabob': 1,
#   'borek': 1,
#   'server terry': 1,
#   'dude': 1,
#   'godfather soundtrack': 1,
#   'ass': 1,
#   'flaws': 1,
#   'vagrant': 1,
#   'thali': 1,
#   'downer': 1,
#   'annoyances': 1,
#   '  buckethead': 1,
#   'precision': 1,
#   'server jonathan': 1,
#   'teeth': 1,
#   'cafe mami': 1,
#   'fusion': 1,
#   'crepes': 1,
#   'goodies': 1,
#   'cheesy goodness': 1,
#   'kindness': 1,
#   'guiness': 1,
#   'awesomeness': 1,
#   'decore': 1,
#   'tho': 1,
#   'landlord': 1,
#   'beet': 1,
#   'wraps': 1,
#   'blaze': 1,
#   'blessing': 1,
#   'bathroom ugh': 1,
#   'pancakes': 1,
#   'cheapskates': 1,
#   'prix fixe': 1,
#   'laidback': 1,
#   'cashier baristas': 1,
#   'trick': 1,
#   'nigiri': 1,
#   'shrine': 1,
#   '0': 1,
#   'somerville': 1,
#   'barbeque': 1,
#   'comers': 1,
#   'butternut': 1,
#   'hummus bowls': 1,
#   'price bump': 1,
#   'ahh': 1,
#   'mahogany': 1,
#   'deserts': 1,
#   'craigie': 1,
#   'server carla': 1,
#   'cheesecake': 1,
#   'legs': 1,
#   'thank': 1,
#   '  guacamole': 1,
#   'aggression': 1,
#   'salmon crudo': 1,
#   'price cons': 1,
#   'apocalypse': 1,
#   'giulia': 1,
#   'guy cashier': 1,
#   'monkfish': 1,
#   'donkey': 1,
#   'fish tacos': 1,
#   'meatballs': 1,
#   'butchering': 1,
#   'darwins': 1,
#   'hallmark': 1,
#   'stipend': 1,
#   'yelp': 1,
#   'riblets': 1,
#   'truffle': 1,
#   'refill': 1,
#   'emails': 1,
#   'outliers': 1,
#   'ok': 1,
#   'eyes': 1,
#   'sushi plates': 1,
#   'dings': 1,
#   'microbrews': 1,
#   'sucks': 1,
#   'bust': 1,
#   "s'mores": 1,
#   'desert sucks': 1,
#   'fiance': 1,
#   'honeycomb': 1,
#   'spuds': 1,
#   'amelia': 1,
#   'tempura': 1,
#   'setter': 1,
#   'lemonade': 1,
#   'ipa': 1,
#   'costumer': 1,
#   'lawn': 1,
#   'benedetto': 1,
#   'remorse': 1,
#   'chardonnay': 1,
#   'newbies': 1,
#   'corn loaf': 1,
#   'creatures': 1,
#   'galaxy': 1,
#   'lacks pop': 1,
#   'food lacks': 1,
#   'trivia contest': 1,
#   'band': 1,
#   'vine': 1,
#   'curries': 1,
#   'cordon bleu': 1,
#   'service waitress': 1,
#   'eggnog shake': 1,
#   'veggie burrito': 1,
#   'sabor': 1,
#   'vomit': 1,
#   'moly': 1,
#   'hut': 1,
#   'miserable': 1,
#   'coma': 1,
#   '6.50': 1,
#   'classics': 1,
#   'draft cons': 1,
#   'precise': 1,
#   'allergy symptoms': 1,
#   'wine pours': 1,
#   'midweek': 1,
#   'tab': 1,
#   'salsas': 1,
#   'tavern': 1,
#   'insures': 1,
#   'reproach': 1,
#   'sirloin': 1,
#   'shawarma': 1,
#   'soda refills': 1,
#   'kalbi': 1,
#   'fish nets': 1,
#   'porter': 1,
#   'resourcefulness': 1,
#   'frustrations': 1,
#   'bluefish': 1,
#   '  swordfish': 1,
#   'service matt': 1,
#   'trifecta': 1,
#   'homestyle': 1,
#   'confusion': 1,
#   'raccoon': 1,
#   'duck tracks cons': 1,
#   'daughter': 1,
#   'gimmick': 1,
#   'jose': 1,
#   'jamon': 1,
#   'rude': 1,
#   'haze': 1,
#   'flu swab': 1,
#   'flu symptoms': 1,
#   'poke': 1,
#   'cashier': 1,
#   'stormy': 1,
#   'migas': 1,
#   'character': 1,
#   'eatin': 1,
#   'preps': 1,
#   'yawn': 1,
#   'tails': 1,
#   'bourbon': 1,
#   'refresh': 1,
#   'outrages': 1,
#   'surfaces': 1,
#   'sexist': 1,
#   'brady': 1,
#   'propaganda': 1,
#   'posters': 1,
#   'negro': 1,
#   'nook': 1,
#   'lemme': 1,
#   'tricky': 1,
#   'doofuses': 1,
#   '  desert': 1,
#   'alex': 1,
#   'lipstick': 1,
#   'shaped': 1,
#   'rings': 1,
#   'presentations': 1,
#   'fan': 1,
#   'liver pat': 1,
#   '7.50': 1,
#   'pedro': 1,
#   'lefty': 1,
#   'amuse bouche': 1,
#   'p.': 1,
#   'zuchinni ravioli': 1,
#   'greatness': 1,
#   'tile': 1,
#   'wi': 1,
#   'onion rings': 1,
#   'saffron vanilla pudding': 1,
#   'speakeasy': 1,
#   'woo': 1,
#   'frat': 1,
#   'sandwich lover': 1,
#   'pairing': 1,
#   'pricetag': 1,
#   'pillows': 1,
#   '2.95': 1,
#   'tomodachi': 1,
#   'aloe vera': 1,
#   'bowl cons': 1,
#   'proprietor': 1,
#   'proprietors': 1,
#   'inability': 1,
#   'grill': 1,
#   'novelties': 1,
#   'florentine cannoli': 1,
#   'films': 1,
#   'soy latte': 1,
#   'earth': 1,
#   'okay': 1,
#   'ceu': 1,
#   'breeze': 1,
#   'rug': 1,
#   'tuna tartare': 1,
#   'trickster': 1,
#   'tori': 1,
#   'tableware': 1,
#   'digs': 1,
#   'maharaja': 1,
#   'halwa': 1,
#   'nutella': 1,
#   'almond': 1,
#   'prices minuses': 1,
#   'charade': 1,
#   'tummy': 1,
#   'asides': 1,
#   'sal': 1,
#   'trout pan': 1,
#   'foo': 1,
#   'twists': 1,
#   'aquariums': 1,
#   'blowfish': 1,
#   'mattress': 1,
#   'cup': 1,
#   'desi dhaba': 1,
#   'pinnacle': 1,
#   'wi fi': 1,
#   'carafe': 1,
#   'marcus': 1,
#   'bastards': 1,
#   'fairness': 1,
#   'chef lin': 1,
#   'emilio': 1,
#   'cameron': 1,
#   'providence': 1,
#   'bs': 1,
#   'discoveries': 1,
#   'impressions': 1,
#   'ordeal': 1,
#   'oyster knife': 1,
#   'despina': 1,
#   'erik': 1,
#   'tatiana': 1,
#   'sweeteners': 1,
#   'chummy': 1,
#   'interval': 1,
#   'sushi sashimi': 1,
#   'pineapple': 1,
#   'disbelief': 1,
#   'lapse': 1,
#   'homer': 1,
#   'boo': 1,
#   'butter shake': 1,
#   'worshippers': 1,
#   'vanilla custard': 1,
#   'pastry crust': 1,
#   'color shake': 1,
#   'champion': 1,
#   'custard': 1,
#   'kolsch': 1,
#   'grilling': 1,
#   'nutshell': 1,
#   'asians': 1,
#   'abv': 1,
#   'favors': 1,
#   '  shake': 1,
#   'caramel shake': 1,
#   'milk capp': 1,
#   'hotpot combo': 1,
#   'max': 1}}

# %%
# user_weights.to_csv('user_weights10_01052021_0.20.csv',index=False)

# %%
restaurant_ratings = pd.read_csv("restaurant_ratings_05052021_0.20.csv")
user_ratings = pd.read_csv("user_weights_glove_05052021_0.20.csv")
dataset.head()
# Out:
#                 review_id             business_id                 user_id  \
# 0  0mOuimxEtWuv63REW07u5g  PYDzfxSLUCCwQysbOkFSVA  k0d3Jnxulohu1HdJj1Hfkg
# 1  kCyJd4kZ_nzf67myR6ZbBA  CoZmZKv2lCYd-UoAsAUobA  u0x3SXagjYDbI2N4sgJ0Tw
# 2  vwaXupz9HVDC5hLqV5M6Eg  ch1ercqwoNLpQLxpTb90KQ  80MUDP_Ny_J8jeShVxzdlw
# 3  SjyigQPHeo5DEMt3Y0xXyQ  HxegWRjhi7m73mXRI8qQIg  p8yQsVA51dzkc9cecDpvrw
# 4  0pjigXXVTpXvfdO4phZoGg  ch1ercqwoNLpQLxpTb90KQ  byro3oSQQ1gRESKlfiAqtQ
#
#    stars                                               text  \
# 0    4.0  This a great place to go to be social with a g...
# 1    4.0  This restaurant is delicious! I've had Ethiopi...
# 2    5.0  Great spot. Comfortable little joint smack dab...
# 3    4.0  I mostly eat here at lunch, for the tremendous...
# 4    2.0  Highlights: Recently revisited BTS -- one of m...
#
#                   date  useful  funny  cool lang           businessname
# 0  2014-02-23 22:02:44       1      0     0   en             State Park
# 1  2015-10-07 21:21:56       0      0     0   en      Asmara Restaurant
# 2  2014-06-11 15:27:40       1      1     2   en        Boston Tea Stop
# 3  2007-05-17 13:48:57       3      0     2   en  Rangzen Tibetan Place
# 4  2010-11-22 07:06:31       5      2     8   en        Boston Tea Stop

# %% [markdown]
# #### Combined Dataset

# %%
combined = dataset.merge(restaurant_ratings,left_on='business_id',right_on='restaurant').merge(user_ratings,left_on='user_id',right_on='user')
combined = combined[["review_id","business_id","food_ratings","service_ratings","ambience_ratings","price_ratings","user_id","food_weight","service_weight","ambience_weight","price_weight"]]
combined.to_csv("combined.csv",index=False)

# %%
pd.read_csv("combined.csv")
# Out:
#                      review_id             business_id  food_ratings  \
# 0       0mOuimxEtWuv63REW07u5g  PYDzfxSLUCCwQysbOkFSVA      2.475728
# 1       5nodndnhlTRSNBtDtXb70w  PYDzfxSLUCCwQysbOkFSVA      2.475728
# 2       JMp7GaSu3OAguLZQWc1BOg  PKnj9SK8M9aSrWpf0rQtPg      3.348624
# 3       Ua0-TPKLFshpNOKQaVXBKw  FxveeHL_B0Kkz1KjPKyF3A      2.763158
# 4       mMKHamzU0MvMoUKyXNthQA  A3D8gBGNmt51kvcI0GkaGQ      3.517007
# ...                        ...                     ...           ...
# 109098  qGDjnd8rcQLITdebxESRNw  ovIxZ7qvNT76tilujesmIA      3.200000
# 109099  Fr08TOAfEzIIPLN6VF84ig  ovIxZ7qvNT76tilujesmIA      3.200000
# 109100  IMZ9_xIOoxW9adXZTx1HWw  ovIxZ7qvNT76tilujesmIA      3.200000
# 109101  YcJTiZGLQtwxEm7MNsqrYQ  ovIxZ7qvNT76tilujesmIA      3.200000
# 109102  MT0dtLgnZPmUYzXRC2GIMQ  ovIxZ7qvNT76tilujesmIA      3.200000
#
#         service_ratings  ambience_ratings  price_ratings  \
# 0              2.000000          3.000000       0.000000
# 1              2.000000          3.000000       0.000000
# 2              3.518519          4.285714       5.000000
# 3              1.702128          2.500000       0.000000
# 4              2.068966          0.789474       1.666667
# ...                 ...               ...            ...
# 109098         5.000000          0.000000       0.000000
# 109099         5.000000          0.000000       0.000000
# 109100         5.000000          0.000000       0.000000
# 109101         5.000000          0.000000       0.000000
# 109102         5.000000          0.000000       0.000000
#
#                        user_id  food_weight  service_weight  ambience_weight  \
# 0       k0d3Jnxulohu1HdJj1Hfkg        100.0             0.0              0.0
# 1       x9Tu88OtnHpD4jZivjQH2w          NaN             NaN              NaN
# 2       x9Tu88OtnHpD4jZivjQH2w          NaN             NaN              NaN
# 3       x9Tu88OtnHpD4jZivjQH2w          NaN             NaN              NaN
# 4       x9Tu88OtnHpD4jZivjQH2w          NaN             NaN              NaN
# ...                        ...          ...             ...              ...
# 109098  z5EZMQOjb4O1GFWhX_L41w        100.0             0.0              0.0
# 109099  FJKJQEehh4oTTXzttoUF3Q        100.0             0.0              0.0
# 109100  s_GaSif_DbS5pAEUxSoWwQ          NaN             NaN              NaN
# 109101  8Cku0Kg2QXWkTbgXRY2u-g          NaN             NaN              NaN
# 109102  RPB5BwhTYVJ-CteJ-Gw-Hg        100.0             0.0              0.0
#
#         price_weight
# 0                0.0
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 109098           0.0
# 109099           0.0
# 109100           NaN
# 109101           NaN
# 109102           0.0
#
# [109103 rows x 11 columns]
